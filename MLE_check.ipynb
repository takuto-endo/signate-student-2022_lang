# %%
# !nvidia-smi
# Out:
# Fri Aug 19 07:13:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Imports

# %%
# %%capture
# !pip install transformers
# !pip install pytorch-lightning

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
import re

import random
import torch

def set_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

set_seed()

import warnings
warnings.simplefilter('ignore')

import gc

# %%
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/signate_student_cup_2022
train_path = './data/train.csv'
test_path = './data/test.csv'
submit_path = './data/submit_sample.csv'
# Out:
# /content/drive/MyDrive/signate_student_cup_2022

# %%
job_flags = ['Data scientist', 'Machine learning engineer','Software engineer','Consultant']

# %%
def text_cleaning(texts):
    clean_texts = []
    num_lines = []
    num_words = []
    words_chunk = []
    for text in texts:
        clean_lines = []
        # print(text, "\n")
        lines = text.split(r"</li>")
        for line in lines:
            line = remove_tag(line)
            # print(line)
            #バックスラッシュをスペースに置き換え
            clean_line = re.sub(r'[\\]', '', line)
            # clean_line = re.sub(r'[/]', ' and ', line)# test
            # print(clean_line)
            clean_line = clean_line.strip()
            # print(clean_line, "\n")
            clean_line = clean_line + ('' if clean_line.endswith('.') else '.')
            if len(clean_line)!=1:
                # print(clean_line, "\n")
                clean_lines.append(clean_line)
        # print(clean_lines)
        clean_texts.append(' '.join(clean_lines))
        
        num_lines.append(len(clean_lines))
        num_word = len(str(clean_lines).split())
        num_words.append(num_word)
        word_chunk = ((num_word-1)//240)+1
        words_chunk.append(word_chunk)

    return clean_texts, num_lines, num_words, words_chunk

def remove_tag(x):
    p = re.compile(r"<[^>]*?>")
    return p.sub('',x)

# %%
train_data = pd.read_csv(train_path)
train_data['description'], num_lines, num_words, words_chunk = text_cleaning(train_data['description'])
train_data['num_lines'] = num_lines
train_data['num_words'] = num_words
train_data['words_chunk'] = words_chunk
train_data['jobflag'] = train_data['jobflag']-1
train_data.head(20)
# Out:
#     id                                        description  jobflag  num_lines  \
# 0    0  Develop cutting-edge web applications that per...        2          8
# 1    1  Designs and develops high quality, scalable an...        2         15
# 2    2  Functions as a point person for Network Strate...        3          9
# 3    3  Work on the technical design, development, rel...        2          5
# 4    4  Quantify the resources required for a task/pro...        3          2
# 5    5  Participates in standard business and technica...        2          4
# 6    6  Create project plans, establish timelines, and...        3          5
# 7    7  Facilitate pre-sales initiatives, such as live...        3         11
# 8    8  Consolidate dashboards across the team and hel...        0          1
# 9    9  Maintain and improve existing predictive model...        0          4
# 10  10  Optimize deep learning frameworks like TensorF...        1          5
# 11  11  Participate in communication of research metho...        0          3
# 12  12  Project manage complex implementation engageme...        3          4
# 13  13  Research, prototype, identify, and build predi...        1          3
# 14  14  System architecture - collaborating with senio...        2          6
# 15  15  Implement process improvements and automation ...        0          4
# 16  16  Provide subject matter expertise in Emergency ...        3         19
# 17  17  Use AWS AI services (e.g., Personalize), ML pl...        0          2
# 18  18  Energetically promote the Ford Blue Advantage ...        3          6
# 19  19  Support and drive interpretation, socializatio...        0          2
#
#     num_words  words_chunk
# 0         112            1
# 1         221            1
# 2         190            1
# 3          79            1
# 4          33            1
# 5          49            1
# 6          85            1
# 7         105            1
# 8          17            1
# 9          53            1
# 10         64            1
# 11         41            1
# 12         34            1
# 13         39            1
# 14         72            1
# 15         37            1
# 16        178            1
# 17         39            1
# 18         87            1
# 19         29            1

# %%
test_data = pd.read_csv(test_path)
test_data['description'], num_lines, num_words, words_chunk = text_cleaning(test_data['description'])
test_data['num_lines'] = num_lines
test_data['num_words'] = num_words
test_data['words_chunk'] = words_chunk
test_data.head(5)
# Out:
#      id                                        description  num_lines  \
# 0  1516  Building decision-making models and proposing ...          2
# 1  1517  Educate homeowners on the benefits of solar en...          5
# 2  1518  Design, develop, document, and implement web a...          8
# 3  1519  Apply advanced technical expertise and skills ...          6
# 4  1520  Project manage and deliver against our roadmap...          4
#
#    num_words  words_chunk
# 0         30            1
# 1         43            1
# 2         82            1
# 3         81            1
# 4         35            1

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.21.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.8.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 7.8 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
from transformers import pipeline, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('facebook/mbart-large-50-one-to-many-mmt')
mbart_translator = pipeline('translation',
                            model='facebook/mbart-large-50-one-to-many-mmt',
                            src_lang='en_XX', tgt_lang='ja_XX', device=0)

deberta_tokenizer = AutoTokenizer.from_pretrained('microsoft/deberta-base')
roberta_tokenizer = AutoTokenizer.from_pretrained('roberta-base')
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading sentencepiece.bpe.model:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/717 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/474 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
# MLE descriptionの特徴について 何故F1が低いのか
pd.set_option('display.max_rows', 100)
mle_data = train_data[train_data["jobflag"]==1].reset_index(drop=True)
for r in range(len(mle_data)):
    print(mle_data.loc[r, "description"])
    print(mbart_translator(mle_data.loc[r, "description"])[0]["translation_text"])
    deberta_tokens = deberta_tokenizer.convert_ids_to_tokens(deberta_tokenizer(mle_data.loc[r, "description"]).input_ids)
    roberta_tokens = roberta_tokenizer.convert_ids_to_tokens(roberta_tokenizer(mle_data.loc[r, "description"]).input_ids)
    print(f'deberta_tokens: {deberta_tokens}')
    print(f'roberta_tokens: {roberta_tokens} \n')
# Out:
# Optimize deep learning frameworks like TensorFlow, PyTorch, etc. on AMD GPUs in upstream open-source repositories. Collaborate and interact with internal GPU library teams to analyze and optimize training and inference for deep learning. Work in a distributed computing setting to optimize for both scale-up (multi-GPU) and scale-out (multi-node) systems. Work with cutting-edge compiler technologies. Optimize the entire deep learning pipeline including graph compiler integration.
# TensorFlow, PyTorch などの深層学習フレームワークをアップストリームのオープンソースリポジトリの AMD GPU 上で最適化します. 深層学習のためのトレーニングと推論を分析し、最適化するために内部 GPU ライブラリチームと協力し、相互作用します. スケールアップ (マルチGPU) とスケールアウト (マルチノード) システムの両方を最適化するために分散コンピューティング設定で作業します. 最先端のコンパイラテクノロジーで作業します. グラフコンパイラの統合を含む全体の深層学習パイプラインを最適化します.
# deberta_tokens: ['[CLS]', 'Opt', 'imize', 'Ġdeep', 'Ġlearning', 'Ġframeworks', 'Ġlike', 'ĠT', 'ensor', 'Flow', ',', 'ĠPy', 'Tor', 'ch', ',', 'Ġetc', '.', 'Ġon', 'ĠAMD', 'ĠGPUs', 'Ġin', 'Ġupstream', 'Ġopen', '-', 'source', 'Ġrepositories', '.', 'ĠCollabor', 'ate', 'Ġand', 'Ġinteract', 'Ġwith', 'Ġinternal', 'ĠGPU', 'Ġlibrary', 'Ġteams', 'Ġto', 'Ġanalyze', 'Ġand', 'Ġoptimize', 'Ġtraining', 'Ġand', 'Ġinference', 'Ġfor', 'Ġdeep', 'Ġlearning', '.', 'ĠWork', 'Ġin', 'Ġa', 'Ġdistributed', 'Ġcomputing', 'Ġsetting', 'Ġto', 'Ġoptimize', 'Ġfor', 'Ġboth', 'Ġscale', '-', 'up', 'Ġ(', 'multi', '-', 'GPU', ')', 'Ġand', 'Ġscale', '-', 'out', 'Ġ(', 'multi', '-', 'node', ')', 'Ġsystems', '.', 'ĠWork', 'Ġwith', 'Ġcutting', '-', 'edge', 'Ġcompiler', 'Ġtechnologies', '.', 'ĠOptim', 'ize', 'Ġthe', 'Ġentire', 'Ġdeep', 'Ġlearning', 'Ġpipeline', 'Ġincluding', 'Ġgraph', 'Ġcompiler', 'Ġintegration', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Opt', 'imize', 'Ġdeep', 'Ġlearning', 'Ġframeworks', 'Ġlike', 'ĠT', 'ensor', 'Flow', ',', 'ĠPy', 'Tor', 'ch', ',', 'Ġetc', '.', 'Ġon', 'ĠAMD', 'ĠGPUs', 'Ġin', 'Ġupstream', 'Ġopen', '-', 'source', 'Ġrepositories', '.', 'ĠCollabor', 'ate', 'Ġand', 'Ġinteract', 'Ġwith', 'Ġinternal', 'ĠGPU', 'Ġlibrary', 'Ġteams', 'Ġto', 'Ġanalyze', 'Ġand', 'Ġoptimize', 'Ġtraining', 'Ġand', 'Ġinference', 'Ġfor', 'Ġdeep', 'Ġlearning', '.', 'ĠWork', 'Ġin', 'Ġa', 'Ġdistributed', 'Ġcomputing', 'Ġsetting', 'Ġto', 'Ġoptimize', 'Ġfor', 'Ġboth', 'Ġscale', '-', 'up', 'Ġ(', 'multi', '-', 'GPU', ')', 'Ġand', 'Ġscale', '-', 'out', 'Ġ(', 'multi', '-', 'node', ')', 'Ġsystems', '.', 'ĠWork', 'Ġwith', 'Ġcutting', '-', 'edge', 'Ġcompiler', 'Ġtechnologies', '.', 'ĠOptim', 'ize', 'Ġthe', 'Ġentire', 'Ġdeep', 'Ġlearning', 'Ġpipeline', 'Ġincluding', 'Ġgraph', 'Ġcompiler', 'Ġintegration', '.', '</s>']
#
# Research, prototype, identify, and build predictive products. You will write tests to ensure the robustness and reliability of your productionized models. You will guide and mentor team members and help educate the business on the art of the possible.
# 研究, プロトタイプ, 特定, 予測製品を構築します. あなたはあなたの生産モデルの堅牢性と信頼性を確保するためにテストを書きます. あなたはガイドとメンターチームメンバーを助け、可能な芸術上のビジネスを教育します.
# deberta_tokens: ['[CLS]', 'Research', ',', 'Ġprototype', ',', 'Ġidentify', ',', 'Ġand', 'Ġbuild', 'Ġpredictive', 'Ġproducts', '.', 'ĠYou', 'Ġwill', 'Ġwrite', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthe', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', 'Ġof', 'Ġyour', 'Ġproduction', 'ized', 'Ġmodels', '.', 'ĠYou', 'Ġwill', 'Ġguide', 'Ġand', 'Ġmentor', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġhelp', 'Ġeducate', 'Ġthe', 'Ġbusiness', 'Ġon', 'Ġthe', 'Ġart', 'Ġof', 'Ġthe', 'Ġpossible', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Research', ',', 'Ġprototype', ',', 'Ġidentify', ',', 'Ġand', 'Ġbuild', 'Ġpredictive', 'Ġproducts', '.', 'ĠYou', 'Ġwill', 'Ġwrite', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthe', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', 'Ġof', 'Ġyour', 'Ġproduction', 'ized', 'Ġmodels', '.', 'ĠYou', 'Ġwill', 'Ġguide', 'Ġand', 'Ġmentor', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġhelp', 'Ġeducate', 'Ġthe', 'Ġbusiness', 'Ġon', 'Ġthe', 'Ġart', 'Ġof', 'Ġthe', 'Ġpossible', '.', '</s>']
#
# Optimizing our ML model and methods for determining Liveness/Realness of human faces. Delivering optimized models to the app development team for integration in the apps. Communication with both internal and 3rd party technical teams who wish to integrate our models and/or SDK into their apps.
# 人間の顔の生かさ/現実性を決定するためのMLモデルとメソッドの最適化. アプリへの統合のためにアプリ開発チームに最適化されたモデルを配信. 当社のモデルと/またはSDKをアプリケーションに統合したい内部およびサードパーティの技術チームと通信.
# deberta_tokens: ['[CLS]', 'Opt', 'im', 'izing', 'Ġour', 'ĠML', 'Ġmodel', 'Ġand', 'Ġmethods', 'Ġfor', 'Ġdetermining', 'ĠL', 'iveness', '/', 'Real', 'ness', 'Ġof', 'Ġhuman', 'Ġfaces', '.', 'ĠDel', 'ivering', 'Ġoptimized', 'Ġmodels', 'Ġto', 'Ġthe', 'Ġapp', 'Ġdevelopment', 'Ġteam', 'Ġfor', 'Ġintegration', 'Ġin', 'Ġthe', 'Ġapps', '.', 'ĠCommunication', 'Ġwith', 'Ġboth', 'Ġinternal', 'Ġand', 'Ġ3', 'rd', 'Ġparty', 'Ġtechnical', 'Ġteams', 'Ġwho', 'Ġwish', 'Ġto', 'Ġintegrate', 'Ġour', 'Ġmodels', 'Ġand', '/', 'or', 'ĠSDK', 'Ġinto', 'Ġtheir', 'Ġapps', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Opt', 'im', 'izing', 'Ġour', 'ĠML', 'Ġmodel', 'Ġand', 'Ġmethods', 'Ġfor', 'Ġdetermining', 'ĠL', 'iveness', '/', 'Real', 'ness', 'Ġof', 'Ġhuman', 'Ġfaces', '.', 'ĠDel', 'ivering', 'Ġoptimized', 'Ġmodels', 'Ġto', 'Ġthe', 'Ġapp', 'Ġdevelopment', 'Ġteam', 'Ġfor', 'Ġintegration', 'Ġin', 'Ġthe', 'Ġapps', '.', 'ĠCommunication', 'Ġwith', 'Ġboth', 'Ġinternal', 'Ġand', 'Ġ3', 'rd', 'Ġparty', 'Ġtechnical', 'Ġteams', 'Ġwho', 'Ġwish', 'Ġto', 'Ġintegrate', 'Ġour', 'Ġmodels', 'Ġand', '/', 'or', 'ĠSDK', 'Ġinto', 'Ġtheir', 'Ġapps', '.', '</s>']
#
# Work together with the ML team to perform research, testing and evaluation of existing and emerging NLP/ML/DL methods and technologies that could be effectively applied to contractual/legal. Be knowledgeable in and be able to apply NLP techniques in order to maintain and extend the current rule-based, supervised and unsupervised methods. Be knowledgeable in and able to apply ML/DL algorithms and technologies to NLP tasks such as Named Entity Recognition, POS tagging, Parsing, Sentiment Analysis, Clustering, text prediction etc. Understand, assist and improved the existing training maintenance and enrichment process.
# MLチームと協力して、既存のML/ML/DLメソッドとテクノロジーの研究、テスト、評価を実行し、契約/法的に効果的に適用することができます. 既存のルールベースの、監督および監督されていないメソッドを維持し、拡張するためにNLPテクニックを適用することができます. 名前のエンティティ認識、POSタグ付け、パーシング、センチメント分析、クラスタリング、テキスト予測などのNLPタスクにML/DLアルゴリズムとテクノロジーを適用することができます. 既存のトレーニングのメンテナンスと充実プロセスを理解し、支援し、改善しました.
# deberta_tokens: ['[CLS]', 'Work', 'Ġtogether', 'Ġwith', 'Ġthe', 'ĠML', 'Ġteam', 'Ġto', 'Ġperform', 'Ġresearch', ',', 'Ġtesting', 'Ġand', 'Ġevaluation', 'Ġof', 'Ġexisting', 'Ġand', 'Ġemerging', 'ĠN', 'LP', '/', 'ML', '/', 'DL', 'Ġmethods', 'Ġand', 'Ġtechnologies', 'Ġthat', 'Ġcould', 'Ġbe', 'Ġeffectively', 'Ġapplied', 'Ġto', 'Ġcontractual', '/', 'legal', '.', 'ĠBe', 'Ġknowledgeable', 'Ġin', 'Ġand', 'Ġbe', 'Ġable', 'Ġto', 'Ġapply', 'ĠN', 'LP', 'Ġtechniques', 'Ġin', 'Ġorder', 'Ġto', 'Ġmaintain', 'Ġand', 'Ġextend', 'Ġthe', 'Ġcurrent', 'Ġrule', '-', 'based', ',', 'Ġsupervised', 'Ġand', 'Ġun', 'super', 'vised', 'Ġmethods', '.', 'ĠBe', 'Ġknowledgeable', 'Ġin', 'Ġand', 'Ġable', 'Ġto', 'Ġapply', 'ĠML', '/', 'DL', 'Ġalgorithms', 'Ġand', 'Ġtechnologies', 'Ġto', 'ĠN', 'LP', 'Ġtasks', 'Ġsuch', 'Ġas', 'ĠNamed', 'ĠEntity', 'ĠRecogn', 'ition', ',', 'ĠPOS', 'Ġtagging', ',', 'ĠPars', 'ing', ',', 'ĠSent', 'iment', 'ĠAnalysis', ',', 'ĠCl', 'ust', 'ering', ',', 'Ġtext', 'Ġprediction', 'Ġetc', '.', 'ĠUnderstand', ',', 'Ġassist', 'Ġand', 'Ġimproved', 'Ġthe', 'Ġexisting', 'Ġtraining', 'Ġmaintenance', 'Ġand', 'Ġenrichment', 'Ġprocess', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Work', 'Ġtogether', 'Ġwith', 'Ġthe', 'ĠML', 'Ġteam', 'Ġto', 'Ġperform', 'Ġresearch', ',', 'Ġtesting', 'Ġand', 'Ġevaluation', 'Ġof', 'Ġexisting', 'Ġand', 'Ġemerging', 'ĠN', 'LP', '/', 'ML', '/', 'DL', 'Ġmethods', 'Ġand', 'Ġtechnologies', 'Ġthat', 'Ġcould', 'Ġbe', 'Ġeffectively', 'Ġapplied', 'Ġto', 'Ġcontractual', '/', 'legal', '.', 'ĠBe', 'Ġknowledgeable', 'Ġin', 'Ġand', 'Ġbe', 'Ġable', 'Ġto', 'Ġapply', 'ĠN', 'LP', 'Ġtechniques', 'Ġin', 'Ġorder', 'Ġto', 'Ġmaintain', 'Ġand', 'Ġextend', 'Ġthe', 'Ġcurrent', 'Ġrule', '-', 'based', ',', 'Ġsupervised', 'Ġand', 'Ġun', 'super', 'vised', 'Ġmethods', '.', 'ĠBe', 'Ġknowledgeable', 'Ġin', 'Ġand', 'Ġable', 'Ġto', 'Ġapply', 'ĠML', '/', 'DL', 'Ġalgorithms', 'Ġand', 'Ġtechnologies', 'Ġto', 'ĠN', 'LP', 'Ġtasks', 'Ġsuch', 'Ġas', 'ĠNamed', 'ĠEntity', 'ĠRecogn', 'ition', ',', 'ĠPOS', 'Ġtagging', ',', 'ĠPars', 'ing', ',', 'ĠSent', 'iment', 'ĠAnalysis', ',', 'ĠCl', 'ust', 'ering', ',', 'Ġtext', 'Ġprediction', 'Ġetc', '.', 'ĠUnderstand', ',', 'Ġassist', 'Ġand', 'Ġimproved', 'Ġthe', 'Ġexisting', 'Ġtraining', 'Ġmaintenance', 'Ġand', 'Ġenrichment', 'Ġprocess', '.', '</s>']
#
# Implementing appropriate ML algorithms. Research and implement appropriate ML algorithms and tools. Perform statistical analysis and fine-tuning using test results. Train and retrain systems when necessary. Extend existing ML libraries and frameworks. Keep abreast of developments in the field requirements.
# 適切なMLアルゴリズムの実装 適切なMLアルゴリズムとツールの研究と実装 テスト結果を使用して統計分析と微調整を行う 必要に応じてシステムのトレーニングとトレーニング 既存のMLライブラリとフレームワークの拡張 フィールドの要件の開発に最新を保つ
# deberta_tokens: ['[CLS]', 'Im', 'plement', 'ing', 'Ġappropriate', 'ĠML', 'Ġalgorithms', '.', 'ĠResearch', 'Ġand', 'Ġimplement', 'Ġappropriate', 'ĠML', 'Ġalgorithms', 'Ġand', 'Ġtools', '.', 'ĠPerform', 'Ġstatistical', 'Ġanalysis', 'Ġand', 'Ġfine', '-', 'tun', 'ing', 'Ġusing', 'Ġtest', 'Ġresults', '.', 'ĠTrain', 'Ġand', 'Ġret', 'rain', 'Ġsystems', 'Ġwhen', 'Ġnecessary', '.', 'ĠExtend', 'Ġexisting', 'ĠML', 'Ġlibraries', 'Ġand', 'Ġframeworks', '.', 'ĠKeep', 'Ġab', 're', 'ast', 'Ġof', 'Ġdevelopments', 'Ġin', 'Ġthe', 'Ġfield', 'Ġrequirements', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Im', 'plement', 'ing', 'Ġappropriate', 'ĠML', 'Ġalgorithms', '.', 'ĠResearch', 'Ġand', 'Ġimplement', 'Ġappropriate', 'ĠML', 'Ġalgorithms', 'Ġand', 'Ġtools', '.', 'ĠPerform', 'Ġstatistical', 'Ġanalysis', 'Ġand', 'Ġfine', '-', 'tun', 'ing', 'Ġusing', 'Ġtest', 'Ġresults', '.', 'ĠTrain', 'Ġand', 'Ġret', 'rain', 'Ġsystems', 'Ġwhen', 'Ġnecessary', '.', 'ĠExtend', 'Ġexisting', 'ĠML', 'Ġlibraries', 'Ġand', 'Ġframeworks', '.', 'ĠKeep', 'Ġab', 're', 'ast', 'Ġof', 'Ġdevelopments', 'Ġin', 'Ġthe', 'Ġfield', 'Ġrequirements', '.', '</s>']
#
# Contribute to decision-making that will lead to successful delivery of projects.
# プロジェクトの成功につながる意思決定に貢献します。
# deberta_tokens: ['[CLS]', 'Cont', 'ribute', 'Ġto', 'Ġdecision', '-', 'making', 'Ġthat', 'Ġwill', 'Ġlead', 'Ġto', 'Ġsuccessful', 'Ġdelivery', 'Ġof', 'Ġprojects', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Cont', 'ribute', 'Ġto', 'Ġdecision', '-', 'making', 'Ġthat', 'Ġwill', 'Ġlead', 'Ġto', 'Ġsuccessful', 'Ġdelivery', 'Ġof', 'Ġprojects', '.', '</s>']
#
# Collaborate with multiple partner teams such as Business, Technology, Product Management, Legal, Compliance, Strategy and Business Management to deploy solutions into production.
# ビジネス、テクノロジー、プロダクトマネジメント、法務、コンプライアンス、戦略、ビジネスマネジメントなどの複数のパートナーチームと協力し、ソリューションを生産に導入します。
# deberta_tokens: ['[CLS]', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġmultiple', 'Ġpartner', 'Ġteams', 'Ġsuch', 'Ġas', 'ĠBusiness', ',', 'ĠTechnology', ',', 'ĠProduct', 'ĠManagement', ',', 'ĠLegal', ',', 'ĠCompliance', ',', 'ĠStrategy', 'Ġand', 'ĠBusiness', 'ĠManagement', 'Ġto', 'Ġdeploy', 'Ġsolutions', 'Ġinto', 'Ġproduction', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġmultiple', 'Ġpartner', 'Ġteams', 'Ġsuch', 'Ġas', 'ĠBusiness', ',', 'ĠTechnology', ',', 'ĠProduct', 'ĠManagement', ',', 'ĠLegal', ',', 'ĠCompliance', ',', 'ĠStrategy', 'Ġand', 'ĠBusiness', 'ĠManagement', 'Ġto', 'Ġdeploy', 'Ġsolutions', 'Ġinto', 'Ġproduction', '.', '</s>']
#
# Working across the stack to build and deploy web applications.
# スタック全体でWebアプリケーションを構築および展開します。
# deberta_tokens: ['[CLS]', 'Working', 'Ġacross', 'Ġthe', 'Ġstack', 'Ġto', 'Ġbuild', 'Ġand', 'Ġdeploy', 'Ġweb', 'Ġapplications', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Working', 'Ġacross', 'Ġthe', 'Ġstack', 'Ġto', 'Ġbuild', 'Ġand', 'Ġdeploy', 'Ġweb', 'Ġapplications', '.', '</s>']
#
# Build the next-generation platform to support our growth efforts across the world.
# 次世代のプラットフォームを構築し、世界中の成長努力を支援します。
# deberta_tokens: ['[CLS]', 'Build', 'Ġthe', 'Ġnext', '-', 'generation', 'Ġplatform', 'Ġto', 'Ġsupport', 'Ġour', 'Ġgrowth', 'Ġefforts', 'Ġacross', 'Ġthe', 'Ġworld', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Build', 'Ġthe', 'Ġnext', '-', 'generation', 'Ġplatform', 'Ġto', 'Ġsupport', 'Ġour', 'Ġgrowth', 'Ġefforts', 'Ġacross', 'Ġthe', 'Ġworld', '.', '</s>']
#
# Implement end-to-end management of the model lifecycle using MLOps practices.
# MLOpsプラクティスを使用してモデルライフサイクルのエンドツーエンド管理を実装します。
# deberta_tokens: ['[CLS]', 'Im', 'plement', 'Ġend', '-', 'to', '-', 'end', 'Ġmanagement', 'Ġof', 'Ġthe', 'Ġmodel', 'Ġlif', 'ecycle', 'Ġusing', 'ĠML', 'Ops', 'Ġpractices', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Im', 'plement', 'Ġend', '-', 'to', '-', 'end', 'Ġmanagement', 'Ġof', 'Ġthe', 'Ġmodel', 'Ġlif', 'ecycle', 'Ġusing', 'ĠML', 'Ops', 'Ġpractices', '.', '</s>']
#
# Collaborate with the application development team to integrate the computer vision models with the existing backend systems. Build monitoring and evaluation tools for real-time optimization of the application using hardware accelerators. Inspire the entire team (including your cross-functional) partners by bringing new ideas to the table.
# アプリケーション開発チームと連携し、既存のバックエンドシステムとコンピュータビジョンモデルを統合します。ハードウェアアクセラレータを使用してアプリケーションのリアルタイム最適化のための監視および評価ツールを構築します。
# Your input_length: 328 is bigger than 0.9 * max_length: 200. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# deberta_tokens: ['[CLS]', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġthe', 'Ġapplication', 'Ġdevelopment', 'Ġteam', 'Ġto', 'Ġintegrate', 'Ġthe', 'Ġcomputer', 'Ġvision', 'Ġmodels', 'Ġwith', 'Ġthe', 'Ġexisting', 'Ġbackend', 'Ġsystems', '.', 'ĠBuild', 'Ġmonitoring', 'Ġand', 'Ġevaluation', 'Ġtools', 'Ġfor', 'Ġreal', '-', 'time', 'Ġoptimization', 'Ġof', 'Ġthe', 'Ġapplication', 'Ġusing', 'Ġhardware', 'Ġacceler', 'ators', '.', 'ĠInsp', 'ire', 'Ġthe', 'Ġentire', 'Ġteam', 'Ġ(', 'including', 'Ġyour', 'Ġcross', '-', 'functional', ')', 'Ġpartners', 'Ġby', 'Ġbringing', 'Ġnew', 'Ġideas', 'Ġto', 'Ġthe', 'Ġtable', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġthe', 'Ġapplication', 'Ġdevelopment', 'Ġteam', 'Ġto', 'Ġintegrate', 'Ġthe', 'Ġcomputer', 'Ġvision', 'Ġmodels', 'Ġwith', 'Ġthe', 'Ġexisting', 'Ġbackend', 'Ġsystems', '.', 'ĠBuild', 'Ġmonitoring', 'Ġand', 'Ġevaluation', 'Ġtools', 'Ġfor', 'Ġreal', '-', 'time', 'Ġoptimization', 'Ġof', 'Ġthe', 'Ġapplication', 'Ġusing', 'Ġhardware', 'Ġacceler', 'ators', '.', 'ĠInsp', 'ire', 'Ġthe', 'Ġentire', 'Ġteam', 'Ġ(', 'including', 'Ġyour', 'Ġcross', '-', 'functional', ')', 'Ġpartners', 'Ġby', 'Ġbringing', 'Ġnew', 'Ġideas', 'Ġto', 'Ġthe', 'Ġtable', '.', '</s>']
#
# Uses technical expertise with tools/applications (i.e., Cadence, RTL Compiler, etc.) to execute advanced architecture and design of multiple complex blocks and makes suggestions for design protocol. Leads the development of an implementation strategy that meets system requirements and customer needs for team. Works effectively with incomplete, ambiguous or conflicting requirements to successfully resolve complex architecture, design, or verification problems. Reviews the design and verification strategies of ASICs, SoC, and IP cores of team members and develops strategies for complex blocks or IC Packages. Reviews highly complex tests from more junior team members and completes own tests to ensure that bugs are fully understood and analyzed. Runs advanced power checks on multiple complex blocks to ensure design specifications are met; makes recommendations to leadership when specifications are not met. Reviews reports and oversees the process of interpreting reports derived from performance checks to ensure major issues are identified. Stays up to date on technical literature and technological advances and supports the creation of new technology. Regularly communicates with key cross-functional groups (i.e., product management, program management teams) to determine product execution path and communicates this path to team. Drives technical conversation in design or project reviews and project meetings to ensure team's progress on project tasks and best interests are represented. Acts as a tech lead on large projects and owns the outcome of the project.
# 高度なアーキテクチャと複数の複雑なブロックの設計を実行するためにツール/アプリケーション(例:キャデンス、RTLコンパイラなど)の技術的な専門知識を使用し、設計プロトコルの提案を行います。 システム要件とチームの顧客ニーズを満たす実装戦略の開発をリードします。 複雑なアーキテクチャ、設計、または検証の問題を成功に解決するために、不完全な、曖昧なまたは競合する要件で効果的に作業します。 チームメンバーのASIC、SoC、IPコアの設計と検証戦略をレビューし、複雑なブロックまたはICパッケージの戦略を開発します。
# deberta_tokens: ['[CLS]', 'Us', 'es', 'Ġtechnical', 'Ġexpertise', 'Ġwith', 'Ġtools', '/', 'app', 'lic', 'ations', 'Ġ(', 'i', '.', 'e', '.,', 'ĠCad', 'ence', ',', 'ĠRT', 'L', 'ĠComp', 'iler', ',', 'Ġetc', '.)', 'Ġto', 'Ġexecute', 'Ġadvanced', 'Ġarchitecture', 'Ġand', 'Ġdesign', 'Ġof', 'Ġmultiple', 'Ġcomplex', 'Ġblocks', 'Ġand', 'Ġmakes', 'Ġsuggestions', 'Ġfor', 'Ġdesign', 'Ġprotocol', '.', 'ĠLe', 'ads', 'Ġthe', 'Ġdevelopment', 'Ġof', 'Ġan', 'Ġimplementation', 'Ġstrategy', 'Ġthat', 'Ġmeets', 'Ġsystem', 'Ġrequirements', 'Ġand', 'Ġcustomer', 'Ġneeds', 'Ġfor', 'Ġteam', '.', 'ĠWorks', 'Ġeffectively', 'Ġwith', 'Ġincomplete', ',', 'Ġambiguous', 'Ġor', 'Ġconflicting', 'Ġrequirements', 'Ġto', 'Ġsuccessfully', 'Ġresolve', 'Ġcomplex', 'Ġarchitecture', ',', 'Ġdesign', ',', 'Ġor', 'Ġverification', 'Ġproblems', '.', 'ĠReviews', 'Ġthe', 'Ġdesign', 'Ġand', 'Ġverification', 'Ġstrategies', 'Ġof', 'ĠASIC', 's', ',', 'ĠSo', 'C', ',', 'Ġand', 'ĠIP', 'Ġcores', 'Ġof', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġdevelops', 'Ġstrategies', 'Ġfor', 'Ġcomplex', 'Ġblocks', 'Ġor', 'ĠIC', 'ĠPack', 'ages', '.', 'ĠReviews', 'Ġhighly', 'Ġcomplex', 'Ġtests', 'Ġfrom', 'Ġmore', 'Ġjunior', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġcompletes', 'Ġown', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthat', 'Ġbugs', 'Ġare', 'Ġfully', 'Ġunderstood', 'Ġand', 'Ġanalyzed', '.', 'ĠRuns', 'Ġadvanced', 'Ġpower', 'Ġchecks', 'Ġon', 'Ġmultiple', 'Ġcomplex', 'Ġblocks', 'Ġto', 'Ġensure', 'Ġdesign', 'Ġspecifications', 'Ġare', 'Ġmet', ';', 'Ġmakes', 'Ġrecommendations', 'Ġto', 'Ġleadership', 'Ġwhen', 'Ġspecifications', 'Ġare', 'Ġnot', 'Ġmet', '.', 'ĠReviews', 'Ġreports', 'Ġand', 'Ġoversees', 'Ġthe', 'Ġprocess', 'Ġof', 'Ġinterpreting', 'Ġreports', 'Ġderived', 'Ġfrom', 'Ġperformance', 'Ġchecks', 'Ġto', 'Ġensure', 'Ġmajor', 'Ġissues', 'Ġare', 'Ġidentified', '.', 'ĠSt', 'ays', 'Ġup', 'Ġto', 'Ġdate', 'Ġon', 'Ġtechnical', 'Ġliterature', 'Ġand', 'Ġtechnological', 'Ġadvances', 'Ġand', 'Ġsupports', 'Ġthe', 'Ġcreation', 'Ġof', 'Ġnew', 'Ġtechnology', '.', 'ĠRegular', 'ly', 'Ġcommunicates', 'Ġwith', 'Ġkey', 'Ġcross', '-', 'functional', 'Ġgroups', 'Ġ(', 'i', '.', 'e', '.,', 'Ġproduct', 'Ġmanagement', ',', 'Ġprogram', 'Ġmanagement', 'Ġteams', ')', 'Ġto', 'Ġdetermine', 'Ġproduct', 'Ġexecution', 'Ġpath', 'Ġand', 'Ġcommunicates', 'Ġthis', 'Ġpath', 'Ġto', 'Ġteam', '.', 'ĠDri', 'ves', 'Ġtechnical', 'Ġconversation', 'Ġin', 'Ġdesign', 'Ġor', 'Ġproject', 'Ġreviews', 'Ġand', 'Ġproject', 'Ġmeetings', 'Ġto', 'Ġensure', 'Ġteam', "'s", 'Ġprogress', 'Ġon', 'Ġproject', 'Ġtasks', 'Ġand', 'Ġbest', 'Ġinterests', 'Ġare', 'Ġrepresented', '.', 'ĠActs', 'Ġas', 'Ġa', 'Ġtech', 'Ġlead', 'Ġon', 'Ġlarge', 'Ġprojects', 'Ġand', 'Ġowns', 'Ġthe', 'Ġoutcome', 'Ġof', 'Ġthe', 'Ġproject', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Us', 'es', 'Ġtechnical', 'Ġexpertise', 'Ġwith', 'Ġtools', '/', 'app', 'lic', 'ations', 'Ġ(', 'i', '.', 'e', '.,', 'ĠCad', 'ence', ',', 'ĠRT', 'L', 'ĠComp', 'iler', ',', 'Ġetc', '.)', 'Ġto', 'Ġexecute', 'Ġadvanced', 'Ġarchitecture', 'Ġand', 'Ġdesign', 'Ġof', 'Ġmultiple', 'Ġcomplex', 'Ġblocks', 'Ġand', 'Ġmakes', 'Ġsuggestions', 'Ġfor', 'Ġdesign', 'Ġprotocol', '.', 'ĠLe', 'ads', 'Ġthe', 'Ġdevelopment', 'Ġof', 'Ġan', 'Ġimplementation', 'Ġstrategy', 'Ġthat', 'Ġmeets', 'Ġsystem', 'Ġrequirements', 'Ġand', 'Ġcustomer', 'Ġneeds', 'Ġfor', 'Ġteam', '.', 'ĠWorks', 'Ġeffectively', 'Ġwith', 'Ġincomplete', ',', 'Ġambiguous', 'Ġor', 'Ġconflicting', 'Ġrequirements', 'Ġto', 'Ġsuccessfully', 'Ġresolve', 'Ġcomplex', 'Ġarchitecture', ',', 'Ġdesign', ',', 'Ġor', 'Ġverification', 'Ġproblems', '.', 'ĠReviews', 'Ġthe', 'Ġdesign', 'Ġand', 'Ġverification', 'Ġstrategies', 'Ġof', 'ĠASIC', 's', ',', 'ĠSo', 'C', ',', 'Ġand', 'ĠIP', 'Ġcores', 'Ġof', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġdevelops', 'Ġstrategies', 'Ġfor', 'Ġcomplex', 'Ġblocks', 'Ġor', 'ĠIC', 'ĠPack', 'ages', '.', 'ĠReviews', 'Ġhighly', 'Ġcomplex', 'Ġtests', 'Ġfrom', 'Ġmore', 'Ġjunior', 'Ġteam', 'Ġmembers', 'Ġand', 'Ġcompletes', 'Ġown', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthat', 'Ġbugs', 'Ġare', 'Ġfully', 'Ġunderstood', 'Ġand', 'Ġanalyzed', '.', 'ĠRuns', 'Ġadvanced', 'Ġpower', 'Ġchecks', 'Ġon', 'Ġmultiple', 'Ġcomplex', 'Ġblocks', 'Ġto', 'Ġensure', 'Ġdesign', 'Ġspecifications', 'Ġare', 'Ġmet', ';', 'Ġmakes', 'Ġrecommendations', 'Ġto', 'Ġleadership', 'Ġwhen', 'Ġspecifications', 'Ġare', 'Ġnot', 'Ġmet', '.', 'ĠReviews', 'Ġreports', 'Ġand', 'Ġoversees', 'Ġthe', 'Ġprocess', 'Ġof', 'Ġinterpreting', 'Ġreports', 'Ġderived', 'Ġfrom', 'Ġperformance', 'Ġchecks', 'Ġto', 'Ġensure', 'Ġmajor', 'Ġissues', 'Ġare', 'Ġidentified', '.', 'ĠSt', 'ays', 'Ġup', 'Ġto', 'Ġdate', 'Ġon', 'Ġtechnical', 'Ġliterature', 'Ġand', 'Ġtechnological', 'Ġadvances', 'Ġand', 'Ġsupports', 'Ġthe', 'Ġcreation', 'Ġof', 'Ġnew', 'Ġtechnology', '.', 'ĠRegular', 'ly', 'Ġcommunicates', 'Ġwith', 'Ġkey', 'Ġcross', '-', 'functional', 'Ġgroups', 'Ġ(', 'i', '.', 'e', '.,', 'Ġproduct', 'Ġmanagement', ',', 'Ġprogram', 'Ġmanagement', 'Ġteams', ')', 'Ġto', 'Ġdetermine', 'Ġproduct', 'Ġexecution', 'Ġpath', 'Ġand', 'Ġcommunicates', 'Ġthis', 'Ġpath', 'Ġto', 'Ġteam', '.', 'ĠDri', 'ves', 'Ġtechnical', 'Ġconversation', 'Ġin', 'Ġdesign', 'Ġor', 'Ġproject', 'Ġreviews', 'Ġand', 'Ġproject', 'Ġmeetings', 'Ġto', 'Ġensure', 'Ġteam', "'s", 'Ġprogress', 'Ġon', 'Ġproject', 'Ġtasks', 'Ġand', 'Ġbest', 'Ġinterests', 'Ġare', 'Ġrepresented', '.', 'ĠActs', 'Ġas', 'Ġa', 'Ġtech', 'Ġlead', 'Ġon', 'Ġlarge', 'Ġprojects', 'Ġand', 'Ġowns', 'Ġthe', 'Ġoutcome', 'Ġof', 'Ġthe', 'Ġproject', '.', '</s>']
#
# Identify and recreate customer’s issues in lab environment to recommend and clearly communicate resolutions. Work independently and with other members of the technical support team to resolve customer application issues in a timely fashion. Collaborate with Product Managers and Product Design Team in HQ to resolve technical issues and suggest product improvements. Create sample applications, product demos, technical documents and other related items for sales, marketing, and support efforts. Provide technical product training to sales team, channel partners, system integrators, OEMs, and end users. Maintain and improve current knowledge through personal education and training. Stay abreast of upcoming product releases as well as current and future technological trends. Interface with customers in the field in support of new projects or investigate potential quality issues. Other duties as assigned.
# 研究室環境で顧客の問題を特定して再現し、明確に解決策を伝える。 独立して、顧客アプリケーションの問題をタイムリーに解決するために技術サポートチームの他のメンバーと作業する。 製品マネージャーと製品設計チームとHQで技術問題を解決し、製品の改善を提案する。 販売、マーケティング、およびサポート努力のためのサンプルアプリケーション、製品デモ、技術文書およびその他の関連項目を作成する。
# deberta_tokens: ['[CLS]', 'Ident', 'ify', 'Ġand', 'Ġrecreate', 'Ġcustomer', 'âĢ', 'Ļ', 's', 'Ġissues', 'Ġin', 'Ġlab', 'Ġenvironment', 'Ġto', 'Ġrecommend', 'Ġand', 'Ġclearly', 'Ġcommunicate', 'Ġresolutions', '.', 'ĠWork', 'Ġindependently', 'Ġand', 'Ġwith', 'Ġother', 'Ġmembers', 'Ġof', 'Ġthe', 'Ġtechnical', 'Ġsupport', 'Ġteam', 'Ġto', 'Ġresolve', 'Ġcustomer', 'Ġapplication', 'Ġissues', 'Ġin', 'Ġa', 'Ġtimely', 'Ġfashion', '.', 'ĠCollabor', 'ate', 'Ġwith', 'ĠProduct', 'ĠMan', 'agers', 'Ġand', 'ĠProduct', 'ĠDesign', 'ĠTeam', 'Ġin', 'ĠHQ', 'Ġto', 'Ġresolve', 'Ġtechnical', 'Ġissues', 'Ġand', 'Ġsuggest', 'Ġproduct', 'Ġimprovements', '.', 'ĠCreate', 'Ġsample', 'Ġapplications', ',', 'Ġproduct', 'Ġdemos', ',', 'Ġtechnical', 'Ġdocuments', 'Ġand', 'Ġother', 'Ġrelated', 'Ġitems', 'Ġfor', 'Ġsales', ',', 'Ġmarketing', ',', 'Ġand', 'Ġsupport', 'Ġefforts', '.', 'ĠProvide', 'Ġtechnical', 'Ġproduct', 'Ġtraining', 'Ġto', 'Ġsales', 'Ġteam', ',', 'Ġchannel', 'Ġpartners', ',', 'Ġsystem', 'Ġinteg', 'rators', ',', 'ĠOEM', 's', ',', 'Ġand', 'Ġend', 'Ġusers', '.', 'ĠM', 'aintain', 'Ġand', 'Ġimprove', 'Ġcurrent', 'Ġknowledge', 'Ġthrough', 'Ġpersonal', 'Ġeducation', 'Ġand', 'Ġtraining', '.', 'ĠStay', 'Ġab', 're', 'ast', 'Ġof', 'Ġupcoming', 'Ġproduct', 'Ġreleases', 'Ġas', 'Ġwell', 'Ġas', 'Ġcurrent', 'Ġand', 'Ġfuture', 'Ġtechnological', 'Ġtrends', '.', 'ĠInterface', 'Ġwith', 'Ġcustomers', 'Ġin', 'Ġthe', 'Ġfield', 'Ġin', 'Ġsupport', 'Ġof', 'Ġnew', 'Ġprojects', 'Ġor', 'Ġinvestigate', 'Ġpotential', 'Ġquality', 'Ġissues', '.', 'ĠOther', 'Ġduties', 'Ġas', 'Ġassigned', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Ident', 'ify', 'Ġand', 'Ġrecreate', 'Ġcustomer', 'âĢ', 'Ļ', 's', 'Ġissues', 'Ġin', 'Ġlab', 'Ġenvironment', 'Ġto', 'Ġrecommend', 'Ġand', 'Ġclearly', 'Ġcommunicate', 'Ġresolutions', '.', 'ĠWork', 'Ġindependently', 'Ġand', 'Ġwith', 'Ġother', 'Ġmembers', 'Ġof', 'Ġthe', 'Ġtechnical', 'Ġsupport', 'Ġteam', 'Ġto', 'Ġresolve', 'Ġcustomer', 'Ġapplication', 'Ġissues', 'Ġin', 'Ġa', 'Ġtimely', 'Ġfashion', '.', 'ĠCollabor', 'ate', 'Ġwith', 'ĠProduct', 'ĠMan', 'agers', 'Ġand', 'ĠProduct', 'ĠDesign', 'ĠTeam', 'Ġin', 'ĠHQ', 'Ġto', 'Ġresolve', 'Ġtechnical', 'Ġissues', 'Ġand', 'Ġsuggest', 'Ġproduct', 'Ġimprovements', '.', 'ĠCreate', 'Ġsample', 'Ġapplications', ',', 'Ġproduct', 'Ġdemos', ',', 'Ġtechnical', 'Ġdocuments', 'Ġand', 'Ġother', 'Ġrelated', 'Ġitems', 'Ġfor', 'Ġsales', ',', 'Ġmarketing', ',', 'Ġand', 'Ġsupport', 'Ġefforts', '.', 'ĠProvide', 'Ġtechnical', 'Ġproduct', 'Ġtraining', 'Ġto', 'Ġsales', 'Ġteam', ',', 'Ġchannel', 'Ġpartners', ',', 'Ġsystem', 'Ġinteg', 'rators', ',', 'ĠOEM', 's', ',', 'Ġand', 'Ġend', 'Ġusers', '.', 'ĠM', 'aintain', 'Ġand', 'Ġimprove', 'Ġcurrent', 'Ġknowledge', 'Ġthrough', 'Ġpersonal', 'Ġeducation', 'Ġand', 'Ġtraining', '.', 'ĠStay', 'Ġab', 're', 'ast', 'Ġof', 'Ġupcoming', 'Ġproduct', 'Ġreleases', 'Ġas', 'Ġwell', 'Ġas', 'Ġcurrent', 'Ġand', 'Ġfuture', 'Ġtechnological', 'Ġtrends', '.', 'ĠInterface', 'Ġwith', 'Ġcustomers', 'Ġin', 'Ġthe', 'Ġfield', 'Ġin', 'Ġsupport', 'Ġof', 'Ġnew', 'Ġprojects', 'Ġor', 'Ġinvestigate', 'Ġpotential', 'Ġquality', 'Ġissues', '.', 'ĠOther', 'Ġduties', 'Ġas', 'Ġassigned', '.', '</s>']
#
# Development of optimization algorithms for ML operators/layers for the Qualcomm AI SW stack. Development of AI SW stack framework enhancements for optimal resource usage while running a neural network on Qualcomm hardware. Evaluating and optimizing neural networks runtime performance and accuracy. Working with customer teams to enable state of the art network models and new AI SW features to meet customer use-cases. Collaborating with AI Hardware and architecture teams to continuously improve our AI solution.
# Qualcomm AI SWスタックのMLオペレータ/レイヤーの最適化アルゴリズムの開発. Qualcomm ハードウェア上のニューラルネットワークを実行しながら最適なリソース使用のための AI SW スタックのフレームワークの強化. ニューラルネットワークのランタイムパフォーマンスと精度の評価と最適化. 顧客の使用事例に対応するために最先端のネットワークモデルと新しい AI SW 機能を可能にする顧客チームとの作業. AI ハードウェアとアーキテクチャチームとのコラボレーションにより、当社のAI ソリューションを継続的に改善.
# Your input_length: 422 is bigger than 0.9 * max_length: 200. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# deberta_tokens: ['[CLS]', 'Development', 'Ġof', 'Ġoptimization', 'Ġalgorithms', 'Ġfor', 'ĠML', 'Ġoperators', '/', 'l', 'ayers', 'Ġfor', 'Ġthe', 'ĠQualcomm', 'ĠAI', 'ĠSW', 'Ġstack', '.', 'ĠDevelopment', 'Ġof', 'ĠAI', 'ĠSW', 'Ġstack', 'Ġframework', 'Ġenhancements', 'Ġfor', 'Ġoptimal', 'Ġresource', 'Ġusage', 'Ġwhile', 'Ġrunning', 'Ġa', 'Ġneural', 'Ġnetwork', 'Ġon', 'ĠQualcomm', 'Ġhardware', '.', 'ĠEval', 'uating', 'Ġand', 'Ġoptimizing', 'Ġneural', 'Ġnetworks', 'Ġruntime', 'Ġperformance', 'Ġand', 'Ġaccuracy', '.', 'ĠWorking', 'Ġwith', 'Ġcustomer', 'Ġteams', 'Ġto', 'Ġenable', 'Ġstate', 'Ġof', 'Ġthe', 'Ġart', 'Ġnetwork', 'Ġmodels', 'Ġand', 'Ġnew', 'ĠAI', 'ĠSW', 'Ġfeatures', 'Ġto', 'Ġmeet', 'Ġcustomer', 'Ġuse', '-', 'cases', '.', 'ĠCollabor', 'ating', 'Ġwith', 'ĠAI', 'ĠHardware', 'Ġand', 'Ġarchitecture', 'Ġteams', 'Ġto', 'Ġcontinuously', 'Ġimprove', 'Ġour', 'ĠAI', 'Ġsolution', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Development', 'Ġof', 'Ġoptimization', 'Ġalgorithms', 'Ġfor', 'ĠML', 'Ġoperators', '/', 'l', 'ayers', 'Ġfor', 'Ġthe', 'ĠQualcomm', 'ĠAI', 'ĠSW', 'Ġstack', '.', 'ĠDevelopment', 'Ġof', 'ĠAI', 'ĠSW', 'Ġstack', 'Ġframework', 'Ġenhancements', 'Ġfor', 'Ġoptimal', 'Ġresource', 'Ġusage', 'Ġwhile', 'Ġrunning', 'Ġa', 'Ġneural', 'Ġnetwork', 'Ġon', 'ĠQualcomm', 'Ġhardware', '.', 'ĠEval', 'uating', 'Ġand', 'Ġoptimizing', 'Ġneural', 'Ġnetworks', 'Ġruntime', 'Ġperformance', 'Ġand', 'Ġaccuracy', '.', 'ĠWorking', 'Ġwith', 'Ġcustomer', 'Ġteams', 'Ġto', 'Ġenable', 'Ġstate', 'Ġof', 'Ġthe', 'Ġart', 'Ġnetwork', 'Ġmodels', 'Ġand', 'Ġnew', 'ĠAI', 'ĠSW', 'Ġfeatures', 'Ġto', 'Ġmeet', 'Ġcustomer', 'Ġuse', '-', 'cases', '.', 'ĠCollabor', 'ating', 'Ġwith', 'ĠAI', 'ĠHardware', 'Ġand', 'Ġarchitecture', 'Ġteams', 'Ġto', 'Ġcontinuously', 'Ġimprove', 'Ġour', 'ĠAI', 'Ġsolution', '.', '</s>']
#
# Foster Google’s culture and principles within the UX team, while working with the UX Research Manager and UX Program Manager to set standards in executional and operational excellence. Provide leadership, direction, and mentorship for a team of designers across multiple products/solutions. Work with the team to drive strategic alignment across Cloud Healthcare and Life Sciences products and identify opportunities for product alignment opportunities across the Cloud AI and Industry Solutions organization. Build excellent relationships with leaders to efficiently implement user experiences that are cohesive, inclusive, and well-informed. Google is proud to be an equal opportunity workplace and is an affirmative action employer. We are committed to equal employment opportunity regardless of race, color, ancestry, religion, sex, national origin, sexual orientation, age, citizenship, marital status, disability, gender identity or Veteran status. We also consider qualified applicants regardless of criminal histories, consistent with legal requirements. See also Google's EEO Policy and EEO is the Law. If you have a disability or special need that requires accommodation, please let us know by completing our Accommodations for Applicants form. https://careers.google.com/jobs/results/115997018309960390-ux-design-manager/ FULL_TIME Google en-US Waterloo ON Canada USER_EXPERIENCE onsite NoMinimum qualifications:12 years of experience in UX Design. 3 years of experience in managing or leading design teams. A portfolio of UX-focused work samples for web and mobile application. Preferred qualifications:Experience building solutions that are comprised of many products and services. Experience with Command Line Interfaces/API design and/or developer tools. Experience establishing Accessibility focus for products. Ability to communicate complex interaction concepts clearly and persuasively across different audiences and varying levels of the organization.
# Googleは、複数の製品/ソリューションのデザイナーのチームのためのリーダーシップ、方向性、およびメンターシップを提供します. チームとクラウドヘルスケアおよびライフサイエンス製品間の戦略的なアライメントを駆動するために作業し、クラウドAIおよび業界ソリューション組織全体での製品アライメント機会の機会を特定します. コーポレートと優れた関係を構築し、一貫性のある、包括的で、そしてよく知られているユーザーエクスペリエンスを効率的に実装するためにリーダーと優れた関係を構築します. Googleは、平等な機会の職場であり、肯定的な行動の雇用主であることに誇りを持っています. 私たちは、人種、色、祖先、宗教、性別、国籍、性的指向、年齢、市民権、婚姻状態、障害、ジェンダーアイデンティティまたはベテランステータスにかかわ
# deberta_tokens: ['[CLS]', 'F', 'oster', 'ĠGoogle', 'âĢ', 'Ļ', 's', 'Ġculture', 'Ġand', 'Ġprinciples', 'Ġwithin', 'Ġthe', 'ĠUX', 'Ġteam', ',', 'Ġwhile', 'Ġworking', 'Ġwith', 'Ġthe', 'ĠUX', 'ĠResearch', 'ĠManager', 'Ġand', 'ĠUX', 'ĠProgram', 'ĠManager', 'Ġto', 'Ġset', 'Ġstandards', 'Ġin', 'Ġexecution', 'al', 'Ġand', 'Ġoperational', 'Ġexcellence', '.', 'ĠProvide', 'Ġleadership', ',', 'Ġdirection', ',', 'Ġand', 'Ġment', 'orship', 'Ġfor', 'Ġa', 'Ġteam', 'Ġof', 'Ġdesigners', 'Ġacross', 'Ġmultiple', 'Ġproducts', '/', 's', 'olutions', '.', 'ĠWork', 'Ġwith', 'Ġthe', 'Ġteam', 'Ġto', 'Ġdrive', 'Ġstrategic', 'Ġalignment', 'Ġacross', 'ĠCloud', 'ĠHealthcare', 'Ġand', 'ĠLife', 'ĠSciences', 'Ġproducts', 'Ġand', 'Ġidentify', 'Ġopportunities', 'Ġfor', 'Ġproduct', 'Ġalignment', 'Ġopportunities', 'Ġacross', 'Ġthe', 'ĠCloud', 'ĠAI', 'Ġand', 'ĠIndustry', 'ĠSolutions', 'Ġorganization', '.', 'ĠBuild', 'Ġexcellent', 'Ġrelationships', 'Ġwith', 'Ġleaders', 'Ġto', 'Ġefficiently', 'Ġimplement', 'Ġuser', 'Ġexperiences', 'Ġthat', 'Ġare', 'Ġcohesive', ',', 'Ġinclusive', ',', 'Ġand', 'Ġwell', '-', 'informed', '.', 'ĠGoogle', 'Ġis', 'Ġproud', 'Ġto', 'Ġbe', 'Ġan', 'Ġequal', 'Ġopportunity', 'Ġworkplace', 'Ġand', 'Ġis', 'Ġan', 'Ġaffirmative', 'Ġaction', 'Ġemployer', '.', 'ĠWe', 'Ġare', 'Ġcommitted', 'Ġto', 'Ġequal', 'Ġemployment', 'Ġopportunity', 'Ġregardless', 'Ġof', 'Ġrace', ',', 'Ġcolor', ',', 'Ġancestry', ',', 'Ġreligion', ',', 'Ġsex', ',', 'Ġnational', 'Ġorigin', ',', 'Ġsexual', 'Ġorientation', ',', 'Ġage', ',', 'Ġcitizenship', ',', 'Ġmarital', 'Ġstatus', ',', 'Ġdisability', ',', 'Ġgender', 'Ġidentity', 'Ġor', 'ĠVeteran', 'Ġstatus', '.', 'ĠWe', 'Ġalso', 'Ġconsider', 'Ġqualified', 'Ġapplicants', 'Ġregardless', 'Ġof', 'Ġcriminal', 'Ġhistories', ',', 'Ġconsistent', 'Ġwith', 'Ġlegal', 'Ġrequirements', '.', 'ĠSee', 'Ġalso', 'ĠGoogle', "'s", 'ĠE', 'EO', 'ĠPolicy', 'Ġand', 'ĠE', 'EO', 'Ġis', 'Ġthe', 'ĠLaw', '.', 'ĠIf', 'Ġyou', 'Ġhave', 'Ġa', 'Ġdisability', 'Ġor', 'Ġspecial', 'Ġneed', 'Ġthat', 'Ġrequires', 'Ġaccommodation', ',', 'Ġplease', 'Ġlet', 'Ġus', 'Ġknow', 'Ġby', 'Ġcompleting', 'Ġour', 'ĠAcc', 'ommod', 'ations', 'Ġfor', 'ĠApplic', 'ants', 'Ġform', '.', 'Ġhttps', '://', 'care', 'ers', '.', 'google', '.', 'com', '/', 'jobs', '/', 'results', '/', '115', '997', '018', '30', '99', '60', '390', '-', 'ux', '-', 'design', '-', 'manager', '/', 'ĠFULL', '_', 'TIME', 'ĠGoogle', 'Ġen', '-', 'US', 'ĠWaterloo', 'ĠON', 'ĠCanada', 'ĠUS', 'ER', '_', 'EX', 'PER', 'IENCE', 'Ġon', 'site', 'ĠNo', 'Minimum', 'Ġqualifications', ':', '12', 'Ġyears', 'Ġof', 'Ġexperience', 'Ġin', 'ĠUX', 'ĠDesign', '.', 'Ġ3', 'Ġyears', 'Ġof', 'Ġexperience', 'Ġin', 'Ġmanaging', 'Ġor', 'Ġleading', 'Ġdesign', 'Ġteams', '.', 'ĠA', 'Ġportfolio', 'Ġof', 'ĠUX', '-', 'focused', 'Ġwork', 'Ġsamples', 'Ġfor', 'Ġweb', 'Ġand', 'Ġmobile', 'Ġapplication', '.', 'ĠPreferred', 'Ġqualifications', ':', 'Experience', 'Ġbuilding', 'Ġsolutions', 'Ġthat', 'Ġare', 'Ġcomprised', 'Ġof', 'Ġmany', 'Ġproducts', 'Ġand', 'Ġservices', '.', 'ĠExperience', 'Ġwith', 'ĠCommand', 'ĠLine', 'ĠInter', 'faces', '/', 'API', 'Ġdesign', 'Ġand', '/', 'or', 'Ġdeveloper', 'Ġtools', '.', 'ĠExperience', 'Ġestablishing', 'ĠAccess', 'ibility', 'Ġfocus', 'Ġfor', 'Ġproducts', '.', 'ĠAbility', 'Ġto', 'Ġcommunicate', 'Ġcomplex', 'Ġinteraction', 'Ġconcepts', 'Ġclearly', 'Ġand', 'Ġpersu', 'as', 'ively', 'Ġacross', 'Ġdifferent', 'Ġaudiences', 'Ġand', 'Ġvarying', 'Ġlevels', 'Ġof', 'Ġthe', 'Ġorganization', '.', '[SEP]']
# roberta_tokens: ['<s>', 'F', 'oster', 'ĠGoogle', 'âĢ', 'Ļ', 's', 'Ġculture', 'Ġand', 'Ġprinciples', 'Ġwithin', 'Ġthe', 'ĠUX', 'Ġteam', ',', 'Ġwhile', 'Ġworking', 'Ġwith', 'Ġthe', 'ĠUX', 'ĠResearch', 'ĠManager', 'Ġand', 'ĠUX', 'ĠProgram', 'ĠManager', 'Ġto', 'Ġset', 'Ġstandards', 'Ġin', 'Ġexecution', 'al', 'Ġand', 'Ġoperational', 'Ġexcellence', '.', 'ĠProvide', 'Ġleadership', ',', 'Ġdirection', ',', 'Ġand', 'Ġment', 'orship', 'Ġfor', 'Ġa', 'Ġteam', 'Ġof', 'Ġdesigners', 'Ġacross', 'Ġmultiple', 'Ġproducts', '/', 's', 'olutions', '.', 'ĠWork', 'Ġwith', 'Ġthe', 'Ġteam', 'Ġto', 'Ġdrive', 'Ġstrategic', 'Ġalignment', 'Ġacross', 'ĠCloud', 'ĠHealthcare', 'Ġand', 'ĠLife', 'ĠSciences', 'Ġproducts', 'Ġand', 'Ġidentify', 'Ġopportunities', 'Ġfor', 'Ġproduct', 'Ġalignment', 'Ġopportunities', 'Ġacross', 'Ġthe', 'ĠCloud', 'ĠAI', 'Ġand', 'ĠIndustry', 'ĠSolutions', 'Ġorganization', '.', 'ĠBuild', 'Ġexcellent', 'Ġrelationships', 'Ġwith', 'Ġleaders', 'Ġto', 'Ġefficiently', 'Ġimplement', 'Ġuser', 'Ġexperiences', 'Ġthat', 'Ġare', 'Ġcohesive', ',', 'Ġinclusive', ',', 'Ġand', 'Ġwell', '-', 'informed', '.', 'ĠGoogle', 'Ġis', 'Ġproud', 'Ġto', 'Ġbe', 'Ġan', 'Ġequal', 'Ġopportunity', 'Ġworkplace', 'Ġand', 'Ġis', 'Ġan', 'Ġaffirmative', 'Ġaction', 'Ġemployer', '.', 'ĠWe', 'Ġare', 'Ġcommitted', 'Ġto', 'Ġequal', 'Ġemployment', 'Ġopportunity', 'Ġregardless', 'Ġof', 'Ġrace', ',', 'Ġcolor', ',', 'Ġancestry', ',', 'Ġreligion', ',', 'Ġsex', ',', 'Ġnational', 'Ġorigin', ',', 'Ġsexual', 'Ġorientation', ',', 'Ġage', ',', 'Ġcitizenship', ',', 'Ġmarital', 'Ġstatus', ',', 'Ġdisability', ',', 'Ġgender', 'Ġidentity', 'Ġor', 'ĠVeteran', 'Ġstatus', '.', 'ĠWe', 'Ġalso', 'Ġconsider', 'Ġqualified', 'Ġapplicants', 'Ġregardless', 'Ġof', 'Ġcriminal', 'Ġhistories', ',', 'Ġconsistent', 'Ġwith', 'Ġlegal', 'Ġrequirements', '.', 'ĠSee', 'Ġalso', 'ĠGoogle', "'s", 'ĠE', 'EO', 'ĠPolicy', 'Ġand', 'ĠE', 'EO', 'Ġis', 'Ġthe', 'ĠLaw', '.', 'ĠIf', 'Ġyou', 'Ġhave', 'Ġa', 'Ġdisability', 'Ġor', 'Ġspecial', 'Ġneed', 'Ġthat', 'Ġrequires', 'Ġaccommodation', ',', 'Ġplease', 'Ġlet', 'Ġus', 'Ġknow', 'Ġby', 'Ġcompleting', 'Ġour', 'ĠAcc', 'ommod', 'ations', 'Ġfor', 'ĠApplic', 'ants', 'Ġform', '.', 'Ġhttps', '://', 'care', 'ers', '.', 'google', '.', 'com', '/', 'jobs', '/', 'results', '/', '115', '997', '018', '30', '99', '60', '390', '-', 'ux', '-', 'design', '-', 'manager', '/', 'ĠFULL', '_', 'TIME', 'ĠGoogle', 'Ġen', '-', 'US', 'ĠWaterloo', 'ĠON', 'ĠCanada', 'ĠUS', 'ER', '_', 'EX', 'PER', 'IENCE', 'Ġon', 'site', 'ĠNo', 'Minimum', 'Ġqualifications', ':', '12', 'Ġyears', 'Ġof', 'Ġexperience', 'Ġin', 'ĠUX', 'ĠDesign', '.', 'Ġ3', 'Ġyears', 'Ġof', 'Ġexperience', 'Ġin', 'Ġmanaging', 'Ġor', 'Ġleading', 'Ġdesign', 'Ġteams', '.', 'ĠA', 'Ġportfolio', 'Ġof', 'ĠUX', '-', 'focused', 'Ġwork', 'Ġsamples', 'Ġfor', 'Ġweb', 'Ġand', 'Ġmobile', 'Ġapplication', '.', 'ĠPreferred', 'Ġqualifications', ':', 'Experience', 'Ġbuilding', 'Ġsolutions', 'Ġthat', 'Ġare', 'Ġcomprised', 'Ġof', 'Ġmany', 'Ġproducts', 'Ġand', 'Ġservices', '.', 'ĠExperience', 'Ġwith', 'ĠCommand', 'ĠLine', 'ĠInter', 'faces', '/', 'API', 'Ġdesign', 'Ġand', '/', 'or', 'Ġdeveloper', 'Ġtools', '.', 'ĠExperience', 'Ġestablishing', 'ĠAccess', 'ibility', 'Ġfocus', 'Ġfor', 'Ġproducts', '.', 'ĠAbility', 'Ġto', 'Ġcommunicate', 'Ġcomplex', 'Ġinteraction', 'Ġconcepts', 'Ġclearly', 'Ġand', 'Ġpersu', 'as', 'ively', 'Ġacross', 'Ġdifferent', 'Ġaudiences', 'Ġand', 'Ġvarying', 'Ġlevels', 'Ġof', 'Ġthe', 'Ġorganization', '.', '</s>']
#
# Perform experiments and statistical analyses to draw conclusions and take modeling decisions. Study, implement and extend state of the art systems. Take part in regular research reviews and discussions. Build, maintain and extend our open source solutions in the domain.
# 研究、実装、最新のシステムの拡張 定期的な研究レビューとディスカッションに参加 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、拡張 ドメイン内のオープンソースソリューションの構築、維持、拡張 ドメイン内のオープンソースソリューションの構築、拡張
# deberta_tokens: ['[CLS]', 'Per', 'form', 'Ġexperiments', 'Ġand', 'Ġstatistical', 'Ġanalyses', 'Ġto', 'Ġdraw', 'Ġconclusions', 'Ġand', 'Ġtake', 'Ġmodeling', 'Ġdecisions', '.', 'ĠStudy', ',', 'Ġimplement', 'Ġand', 'Ġextend', 'Ġstate', 'Ġof', 'Ġthe', 'Ġart', 'Ġsystems', '.', 'ĠTake', 'Ġpart', 'Ġin', 'Ġregular', 'Ġresearch', 'Ġreviews', 'Ġand', 'Ġdiscussions', '.', 'ĠBuild', ',', 'Ġmaintain', 'Ġand', 'Ġextend', 'Ġour', 'Ġopen', 'Ġsource', 'Ġsolutions', 'Ġin', 'Ġthe', 'Ġdomain', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Per', 'form', 'Ġexperiments', 'Ġand', 'Ġstatistical', 'Ġanalyses', 'Ġto', 'Ġdraw', 'Ġconclusions', 'Ġand', 'Ġtake', 'Ġmodeling', 'Ġdecisions', '.', 'ĠStudy', ',', 'Ġimplement', 'Ġand', 'Ġextend', 'Ġstate', 'Ġof', 'Ġthe', 'Ġart', 'Ġsystems', '.', 'ĠTake', 'Ġpart', 'Ġin', 'Ġregular', 'Ġresearch', 'Ġreviews', 'Ġand', 'Ġdiscussions', '.', 'ĠBuild', ',', 'Ġmaintain', 'Ġand', 'Ġextend', 'Ġour', 'Ġopen', 'Ġsource', 'Ġsolutions', 'Ġin', 'Ġthe', 'Ġdomain', '.', '</s>']
#
# Build and maintain pipelines and benchmarks to improve model performance. Optimize the training process for deep learning models. Design in-truck validation experiments and conduct full-system integration and tests.
# モデルパフォーマンスを向上させるパイプラインとベンチマークを構築し、維持します。ディープラーニングモデルのトレーニングプロセスを最適化します。トラック内の検証実験を設計し、システム全体の統合とテストを実行します。
# deberta_tokens: ['[CLS]', 'Build', 'Ġand', 'Ġmaintain', 'Ġpipelines', 'Ġand', 'Ġbenchmarks', 'Ġto', 'Ġimprove', 'Ġmodel', 'Ġperformance', '.', 'ĠOptim', 'ize', 'Ġthe', 'Ġtraining', 'Ġprocess', 'Ġfor', 'Ġdeep', 'Ġlearning', 'Ġmodels', '.', 'ĠDesign', 'Ġin', '-', 't', 'ruck', 'Ġvalidation', 'Ġexperiments', 'Ġand', 'Ġconduct', 'Ġfull', '-', 'system', 'Ġintegration', 'Ġand', 'Ġtests', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Build', 'Ġand', 'Ġmaintain', 'Ġpipelines', 'Ġand', 'Ġbenchmarks', 'Ġto', 'Ġimprove', 'Ġmodel', 'Ġperformance', '.', 'ĠOptim', 'ize', 'Ġthe', 'Ġtraining', 'Ġprocess', 'Ġfor', 'Ġdeep', 'Ġlearning', 'Ġmodels', '.', 'ĠDesign', 'Ġin', '-', 't', 'ruck', 'Ġvalidation', 'Ġexperiments', 'Ġand', 'Ġconduct', 'Ġfull', '-', 'system', 'Ġintegration', 'Ġand', 'Ġtests', '.', '</s>']
#
# Conceptualize novel computational approaches for prioritizing disease-associated splice variants. Benchmark these methods against existing baseline approaches e.g. using simulations. Document and present progress and results in written or oral reports to other lab members. Prepare manuscripts and external presentations including for consortium meetings. Building standardized Python and conda packages.
# 疾患関連スプライスバリアントの優先順位を決定するための新しい計算アプローチを概念化する. シミュレーションを使用するなど、既存のベースラインアプローチに対してこれらのメソッドをベンチマークする. 他のラボメンバーに書面または口頭レポートで進捗状況と結果を文書化し、提示する. コンソーシアムミーティングを含む手稿と外部プレゼンテーションを準備する. 標準化された Python と conda パッケージの構築.
# deberta_tokens: ['[CLS]', 'Con', 'cept', 'ual', 'ize', 'Ġnovel', 'Ġcomputational', 'Ġapproaches', 'Ġfor', 'Ġpriorit', 'izing', 'Ġdisease', '-', 'associated', 'Ġspl', 'ice', 'Ġvariants', '.', 'ĠBench', 'mark', 'Ġthese', 'Ġmethods', 'Ġagainst', 'Ġexisting', 'Ġbaseline', 'Ġapproaches', 'Ġe', '.', 'g', '.', 'Ġusing', 'Ġsimulations', '.', 'ĠDocument', 'Ġand', 'Ġpresent', 'Ġprogress', 'Ġand', 'Ġresults', 'Ġin', 'Ġwritten', 'Ġor', 'Ġoral', 'Ġreports', 'Ġto', 'Ġother', 'Ġlab', 'Ġmembers', '.', 'ĠPrepare', 'Ġmanuscripts', 'Ġand', 'Ġexternal', 'Ġpresentations', 'Ġincluding', 'Ġfor', 'Ġconsortium', 'Ġmeetings', '.', 'ĠBuilding', 'Ġstandardized', 'ĠPython', 'Ġand', 'Ġcond', 'a', 'Ġpackages', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Con', 'cept', 'ual', 'ize', 'Ġnovel', 'Ġcomputational', 'Ġapproaches', 'Ġfor', 'Ġpriorit', 'izing', 'Ġdisease', '-', 'associated', 'Ġspl', 'ice', 'Ġvariants', '.', 'ĠBench', 'mark', 'Ġthese', 'Ġmethods', 'Ġagainst', 'Ġexisting', 'Ġbaseline', 'Ġapproaches', 'Ġe', '.', 'g', '.', 'Ġusing', 'Ġsimulations', '.', 'ĠDocument', 'Ġand', 'Ġpresent', 'Ġprogress', 'Ġand', 'Ġresults', 'Ġin', 'Ġwritten', 'Ġor', 'Ġoral', 'Ġreports', 'Ġto', 'Ġother', 'Ġlab', 'Ġmembers', '.', 'ĠPrepare', 'Ġmanuscripts', 'Ġand', 'Ġexternal', 'Ġpresentations', 'Ġincluding', 'Ġfor', 'Ġconsortium', 'Ġmeetings', '.', 'ĠBuilding', 'Ġstandardized', 'ĠPython', 'Ġand', 'Ġcond', 'a', 'Ġpackages', '.', '</s>']
#
# Build the large scale systems for ML integrating with GPU, RDMA network and storage system;.
# GPU、RDMAネットワーク、ストレージシステムとMLを統合するための大規模なシステムを構築します。
# deberta_tokens: ['[CLS]', 'Build', 'Ġthe', 'Ġlarge', 'Ġscale', 'Ġsystems', 'Ġfor', 'ĠML', 'Ġintegrating', 'Ġwith', 'ĠGPU', ',', 'ĠRD', 'MA', 'Ġnetwork', 'Ġand', 'Ġstorage', 'Ġsystem', ';', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Build', 'Ġthe', 'Ġlarge', 'Ġscale', 'Ġsystems', 'Ġfor', 'ĠML', 'Ġintegrating', 'Ġwith', 'ĠGPU', ',', 'ĠRD', 'MA', 'Ġnetwork', 'Ġand', 'Ġstorage', 'Ġsystem', ';', '.', '</s>']
#
# Maintain and improve ML SW automation test framework. Test case development from feature requirements and use case analysis. Working with development team for regression report triage, bug analysis and issue tracking.
# ML SW オートメーション テスト フレームワークの維持および改善 機能要件からケース開発およびケース分析の使用 リグレッション レポート トリアージ、バグ 分析および問題トラッキングの開発チームと作業
# deberta_tokens: ['[CLS]', 'M', 'aintain', 'Ġand', 'Ġimprove', 'ĠML', 'ĠSW', 'Ġautomation', 'Ġtest', 'Ġframework', '.', 'ĠTest', 'Ġcase', 'Ġdevelopment', 'Ġfrom', 'Ġfeature', 'Ġrequirements', 'Ġand', 'Ġuse', 'Ġcase', 'Ġanalysis', '.', 'ĠWorking', 'Ġwith', 'Ġdevelopment', 'Ġteam', 'Ġfor', 'Ġregression', 'Ġreport', 'Ġtri', 'age', ',', 'Ġbug', 'Ġanalysis', 'Ġand', 'Ġissue', 'Ġtracking', '.', '[SEP]']
# roberta_tokens: ['<s>', 'M', 'aintain', 'Ġand', 'Ġimprove', 'ĠML', 'ĠSW', 'Ġautomation', 'Ġtest', 'Ġframework', '.', 'ĠTest', 'Ġcase', 'Ġdevelopment', 'Ġfrom', 'Ġfeature', 'Ġrequirements', 'Ġand', 'Ġuse', 'Ġcase', 'Ġanalysis', '.', 'ĠWorking', 'Ġwith', 'Ġdevelopment', 'Ġteam', 'Ġfor', 'Ġregression', 'Ġreport', 'Ġtri', 'age', ',', 'Ġbug', 'Ġanalysis', 'Ġand', 'Ġissue', 'Ġtracking', '.', '</s>']
#
# Research, prototype, identify, and build predictive products. You will write tests to ensure the robustness and reliability of your productionized models.
# 研究, プロトタイプ, 識別, 予測製品を構築. あなたは、生産モデルの堅牢性と信頼性を確保するためにテストを書く.
# deberta_tokens: ['[CLS]', 'Research', ',', 'Ġprototype', ',', 'Ġidentify', ',', 'Ġand', 'Ġbuild', 'Ġpredictive', 'Ġproducts', '.', 'ĠYou', 'Ġwill', 'Ġwrite', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthe', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', 'Ġof', 'Ġyour', 'Ġproduction', 'ized', 'Ġmodels', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Research', ',', 'Ġprototype', ',', 'Ġidentify', ',', 'Ġand', 'Ġbuild', 'Ġpredictive', 'Ġproducts', '.', 'ĠYou', 'Ġwill', 'Ġwrite', 'Ġtests', 'Ġto', 'Ġensure', 'Ġthe', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', 'Ġof', 'Ġyour', 'Ġproduction', 'ized', 'Ġmodels', '.', '</s>']
#
# Actively participate in scoping requirements, ML pipeline design and development, (on-device) ML model development, evaluation and validation.
# スコープ要求、MLパイプライン設計と開発、MLモデル開発、評価、検証に積極的に参加します。
# deberta_tokens: ['[CLS]', 'Act', 'ively', 'Ġparticipate', 'Ġin', 'Ġsc', 'oping', 'Ġrequirements', ',', 'ĠML', 'Ġpipeline', 'Ġdesign', 'Ġand', 'Ġdevelopment', ',', 'Ġ(', 'on', '-', 'device', ')', 'ĠML', 'Ġmodel', 'Ġdevelopment', ',', 'Ġevaluation', 'Ġand', 'Ġvalidation', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Act', 'ively', 'Ġparticipate', 'Ġin', 'Ġsc', 'oping', 'Ġrequirements', ',', 'ĠML', 'Ġpipeline', 'Ġdesign', 'Ġand', 'Ġdevelopment', ',', 'Ġ(', 'on', '-', 'device', ')', 'ĠML', 'Ġmodel', 'Ġdevelopment', ',', 'Ġevaluation', 'Ġand', 'Ġvalidation', '.', '</s>']
#
# Help us build out our MLOps system for tracking, maintaining, interpreting, and retraining our production models. Effectively communicate complex technical results to business partners. Work with a great deal of autonomy to find solutions to complex problems. You’ll be rewarded and recognized for your performance in an environment that will challenge you and give you clear direction on what it takes to succeed in your role as well as provide development for other roles you may be interested in.
# 当社の生産モデルを追跡し、維持し、解釈し、再訓練するためのMLOpsシステムを構築するのに役立ちます。
# deberta_tokens: ['[CLS]', 'Help', 'Ġus', 'Ġbuild', 'Ġout', 'Ġour', 'ĠML', 'Ops', 'Ġsystem', 'Ġfor', 'Ġtracking', ',', 'Ġmaintaining', ',', 'Ġinterpreting', ',', 'Ġand', 'Ġret', 'raining', 'Ġour', 'Ġproduction', 'Ġmodels', '.', 'ĠEffect', 'ively', 'Ġcommunicate', 'Ġcomplex', 'Ġtechnical', 'Ġresults', 'Ġto', 'Ġbusiness', 'Ġpartners', '.', 'ĠWork', 'Ġwith', 'Ġa', 'Ġgreat', 'Ġdeal', 'Ġof', 'Ġautonomy', 'Ġto', 'Ġfind', 'Ġsolutions', 'Ġto', 'Ġcomplex', 'Ġproblems', '.', 'ĠYou', 'âĢ', 'Ļ', 'll', 'Ġbe', 'Ġrewarded', 'Ġand', 'Ġrecognized', 'Ġfor', 'Ġyour', 'Ġperformance', 'Ġin', 'Ġan', 'Ġenvironment', 'Ġthat', 'Ġwill', 'Ġchallenge', 'Ġyou', 'Ġand', 'Ġgive', 'Ġyou', 'Ġclear', 'Ġdirection', 'Ġon', 'Ġwhat', 'Ġit', 'Ġtakes', 'Ġto', 'Ġsucceed', 'Ġin', 'Ġyour', 'Ġrole', 'Ġas', 'Ġwell', 'Ġas', 'Ġprovide', 'Ġdevelopment', 'Ġfor', 'Ġother', 'Ġroles', 'Ġyou', 'Ġmay', 'Ġbe', 'Ġinterested', 'Ġin', '.', '[SEP]']
# ...
# roberta_tokens: ['<s>', 'You', 'Ġwill', 'Ġmonitor', 'Ġdeployed', 'Ġmodels', 'Ġfor', 'Ġmodel', 'Ġdrift', 'Ġand', 'Ġperformance', ',', 'Ġsupport', 'Ġmodel', 'Ġret', 'raining', 'Ġand', 'Ġprovide', 'Ġincident', 'Ġmanagement', 'Ġsupport', '.', 'ĠYou', 'Ġwill', 'Ġmonitor', 'Ġdeployed', 'Ġmodels', 'Ġfor', 'Ġmodel', 'Ġdrift', 'Ġand', 'Ġperformance', ',', 'Ġsupport', 'Ġmodel', 'Ġret', 'raining', 'Ġand', 'Ġprovide', 'Ġincident', 'Ġmanagement', 'Ġsupport', '.', 'ĠBring', 'Ġyour', 'Ġpassion', 'Ġand', 'Ġexpertise', 'Ġ2', '+', 'Ġyears', 'âĢ', 'Ļ', 'Ġexperience', 'Ġdeploying', 'ĠAI', 'Ġmodel', 'Ġpipelines', 'Ġin', 'Ġthe', 'ĠCloud', 'Ġ(', 'AW', 'S', 'Ġpreferred', ')', 'Ġand', 'Ġintegrating', 'ĠAI', '/', 'ML', 'Ġand', 'Ġother', 'ĠCloud', 'Ġservices', 'Ġinto', 'Ġlarge', '-', 'scale', 'Ġproduction', 'Ġapplications', '.', 'ĠProf', 'iciency', 'Ġin', 'Ġat', 'Ġleast', 'Ġone', 'Ġmodern', 'Ġprogramming', 'Ġlanguage', 'Ġlike', 'ĠPython', 'Ġand', 'ĠML', 'Ġframeworks', 'Ġlike', 'ĠT', 'ensor', 'flow', ',', 'ĠSci', 'kit', '-', 'learn', ',', 'ĠPy', 'tor', 'ch', 'Ġ,', 'ĠNum', 'Py', ',', 'ĠPand', 'as', 'Ġetc', '.', 'ĠSolid', 'Ġunderstanding', 'Ġand', 'Ġ2', '+', 'Ġyears', 'âĢ', 'Ļ', 'Ġexperience', 'Ġworking', 'Ġwith', 'Ġone', 'Ġof', 'Ġthe', 'Ġcloud', 'Ġcomputing', 'Ġenvironments', 'Ġsuch', 'Ġas', 'ĠAWS', ',', 'ĠAzure', ',', 'ĠGoogle', 'ĠCloud', '.', 'ĠMust', 'Ġpossess', 'Ġstrong', 'Ġverbal', 'Ġand', 'Ġwritten', 'Ġcommunication', 'Ġskills', ',', 'Ġbe', 'Ġself', '-', 'driven', ',', 'Ġaccountable', 'Ġand', 'Ġconstant', 'Ġlear', 'ner', '.', 'ĠExperience', 'Ġworking', 'Ġfor', 'Ġa', 'Ġlarge', 'Ġretail', 'Ġcompany', 'Ġis', 'Ġpreferred', '.', '</s>']
#
# Communicate and collaborate with a network of experienced architects and designers around the world. Identify complex technical problems, break them down, summarize possible solutions. Work with architects to propose innovative solutions that can be implemented in HW, validated by developing various models/simulators.
# 世界中の経験豊富なアーキテクトやデザイナーのネットワークと交流し、協力します. 複雑な技術的な問題を特定します, それらを分解します, 可能なソリューションをまとめます. さまざまなモデル/シミュレータを開発することによって検証された, HWで実装することができる革新的なソリューションを提案するためにアーキテクトと作業します.
# deberta_tokens: ['[CLS]', 'Commun', 'icate', 'Ġand', 'Ġcollaborate', 'Ġwith', 'Ġa', 'Ġnetwork', 'Ġof', 'Ġexperienced', 'Ġarchitects', 'Ġand', 'Ġdesigners', 'Ġaround', 'Ġthe', 'Ġworld', '.', 'ĠIdent', 'ify', 'Ġcomplex', 'Ġtechnical', 'Ġproblems', ',', 'Ġbreak', 'Ġthem', 'Ġdown', ',', 'Ġsummarize', 'Ġpossible', 'Ġsolutions', '.', 'ĠWork', 'Ġwith', 'Ġarchitects', 'Ġto', 'Ġpropose', 'Ġinnovative', 'Ġsolutions', 'Ġthat', 'Ġcan', 'Ġbe', 'Ġimplemented', 'Ġin', 'ĠHW', ',', 'Ġvalidated', 'Ġby', 'Ġdeveloping', 'Ġvarious', 'Ġmodels', '/', 'sim', 'ulators', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Commun', 'icate', 'Ġand', 'Ġcollaborate', 'Ġwith', 'Ġa', 'Ġnetwork', 'Ġof', 'Ġexperienced', 'Ġarchitects', 'Ġand', 'Ġdesigners', 'Ġaround', 'Ġthe', 'Ġworld', '.', 'ĠIdent', 'ify', 'Ġcomplex', 'Ġtechnical', 'Ġproblems', ',', 'Ġbreak', 'Ġthem', 'Ġdown', ',', 'Ġsummarize', 'Ġpossible', 'Ġsolutions', '.', 'ĠWork', 'Ġwith', 'Ġarchitects', 'Ġto', 'Ġpropose', 'Ġinnovative', 'Ġsolutions', 'Ġthat', 'Ġcan', 'Ġbe', 'Ġimplemented', 'Ġin', 'ĠHW', ',', 'Ġvalidated', 'Ġby', 'Ġdeveloping', 'Ġvarious', 'Ġmodels', '/', 'sim', 'ulators', '.', '</s>']
#
# Research and develop innovative ML based solutions to some of Operations' hardest problems. Communicate AI capabilities and results to both technical and non-technical audiences. Document approaches taken, techniques used and processes followed.
# いくつかのオペレーションの最も困難な問題に対する革新的なMLベースのソリューションを研究開発します。
# deberta_tokens: ['[CLS]', 'Research', 'Ġand', 'Ġdevelop', 'Ġinnovative', 'ĠML', 'Ġbased', 'Ġsolutions', 'Ġto', 'Ġsome', 'Ġof', 'ĠOperations', "'", 'Ġhardest', 'Ġproblems', '.', 'ĠCommun', 'icate', 'ĠAI', 'Ġcapabilities', 'Ġand', 'Ġresults', 'Ġto', 'Ġboth', 'Ġtechnical', 'Ġand', 'Ġnon', '-', 'technical', 'Ġaudiences', '.', 'ĠDocument', 'Ġapproaches', 'Ġtaken', ',', 'Ġtechniques', 'Ġused', 'Ġand', 'Ġprocesses', 'Ġfollowed', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Research', 'Ġand', 'Ġdevelop', 'Ġinnovative', 'ĠML', 'Ġbased', 'Ġsolutions', 'Ġto', 'Ġsome', 'Ġof', 'ĠOperations', "'", 'Ġhardest', 'Ġproblems', '.', 'ĠCommun', 'icate', 'ĠAI', 'Ġcapabilities', 'Ġand', 'Ġresults', 'Ġto', 'Ġboth', 'Ġtechnical', 'Ġand', 'Ġnon', '-', 'technical', 'Ġaudiences', '.', 'ĠDocument', 'Ġapproaches', 'Ġtaken', ',', 'Ġtechniques', 'Ġused', 'Ġand', 'Ġprocesses', 'Ġfollowed', '.', '</s>']
#
# Work with Product Managers to understand the business, formulate the problems, come up with the solutions.
# プロダクトマネージャーと協力してビジネスを理解し、問題を策定し、解決策を提案します。
# deberta_tokens: ['[CLS]', 'Work', 'Ġwith', 'ĠProduct', 'ĠMan', 'agers', 'Ġto', 'Ġunderstand', 'Ġthe', 'Ġbusiness', ',', 'Ġformulate', 'Ġthe', 'Ġproblems', ',', 'Ġcome', 'Ġup', 'Ġwith', 'Ġthe', 'Ġsolutions', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Work', 'Ġwith', 'ĠProduct', 'ĠMan', 'agers', 'Ġto', 'Ġunderstand', 'Ġthe', 'Ġbusiness', ',', 'Ġformulate', 'Ġthe', 'Ġproblems', ',', 'Ġcome', 'Ġup', 'Ġwith', 'Ġthe', 'Ġsolutions', '.', '</s>']
#
# Collaborate with the application development team to integrate the computer vision models with the existing backend systems. Build monitoring tools and automate the inference pipeline. Develop CI/CD pipelines for deployment on cloud and edge. Inspire the entire team (including your cross-functional) partners by bringing new ideas to the table.
# 既存のバックエンドシステムとコンピュータビジョンモデルを統合するためにアプリケーション開発チームと協力します。監視ツールを構築し、推論パイプラインを自動化します。
# deberta_tokens: ['[CLS]', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġthe', 'Ġapplication', 'Ġdevelopment', 'Ġteam', 'Ġto', 'Ġintegrate', 'Ġthe', 'Ġcomputer', 'Ġvision', 'Ġmodels', 'Ġwith', 'Ġthe', 'Ġexisting', 'Ġbackend', 'Ġsystems', '.', 'ĠBuild', 'Ġmonitoring', 'Ġtools', 'Ġand', 'Ġautomate', 'Ġthe', 'Ġinference', 'Ġpipeline', '.', 'ĠDevelop', 'ĠCI', '/', 'CD', 'Ġpipelines', 'Ġfor', 'Ġdeployment', 'Ġon', 'Ġcloud', 'Ġand', 'Ġedge', '.', 'ĠInsp', 'ire', 'Ġthe', 'Ġentire', 'Ġteam', 'Ġ(', 'including', 'Ġyour', 'Ġcross', '-', 'functional', ')', 'Ġpartners', 'Ġby', 'Ġbringing', 'Ġnew', 'Ġideas', 'Ġto', 'Ġthe', 'Ġtable', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġthe', 'Ġapplication', 'Ġdevelopment', 'Ġteam', 'Ġto', 'Ġintegrate', 'Ġthe', 'Ġcomputer', 'Ġvision', 'Ġmodels', 'Ġwith', 'Ġthe', 'Ġexisting', 'Ġbackend', 'Ġsystems', '.', 'ĠBuild', 'Ġmonitoring', 'Ġtools', 'Ġand', 'Ġautomate', 'Ġthe', 'Ġinference', 'Ġpipeline', '.', 'ĠDevelop', 'ĠCI', '/', 'CD', 'Ġpipelines', 'Ġfor', 'Ġdeployment', 'Ġon', 'Ġcloud', 'Ġand', 'Ġedge', '.', 'ĠInsp', 'ire', 'Ġthe', 'Ġentire', 'Ġteam', 'Ġ(', 'including', 'Ġyour', 'Ġcross', '-', 'functional', ')', 'Ġpartners', 'Ġby', 'Ġbringing', 'Ġnew', 'Ġideas', 'Ġto', 'Ġthe', 'Ġtable', '.', '</s>']
#
# Responsible for the development and maintenance of key system features. Will work with other team members to investigate design approaches, prototype technology and evaluate technical feasibility. Will establish architectural principles, select design patterns and then mentor team members on their appropriate application. Team Locations:Toronto. Vancouver. Virtual in Canada. Key job responsibilities.
# 主要なシステム機能の開発とメンテナンスの責任. 他のチームメンバーと協力して設計アプローチを調査します, プロトタイプテクノロジーと技術的実行可能性を評価します. アーキテクチャの原則を確立します, 設計パターンを選択し、適切なアプリケーションにチームメンバーを指導します. チームの場所:トーロント. バンクーバー. カナダでバーチャル. 主要な仕事責任.
# deberta_tokens: ['[CLS]', 'Resp', 'ons', 'ible', 'Ġfor', 'Ġthe', 'Ġdevelopment', 'Ġand', 'Ġmaintenance', 'Ġof', 'Ġkey', 'Ġsystem', 'Ġfeatures', '.', 'ĠWill', 'Ġwork', 'Ġwith', 'Ġother', 'Ġteam', 'Ġmembers', 'Ġto', 'Ġinvestigate', 'Ġdesign', 'Ġapproaches', ',', 'Ġprototype', 'Ġtechnology', 'Ġand', 'Ġevaluate', 'Ġtechnical', 'Ġfeasibility', '.', 'ĠWill', 'Ġestablish', 'Ġarchitectural', 'Ġprinciples', ',', 'Ġselect', 'Ġdesign', 'Ġpatterns', 'Ġand', 'Ġthen', 'Ġmentor', 'Ġteam', 'Ġmembers', 'Ġon', 'Ġtheir', 'Ġappropriate', 'Ġapplication', '.', 'ĠTeam', 'ĠLocations', ':', 'Toronto', '.', 'ĠVancouver', '.', 'ĠVirtual', 'Ġin', 'ĠCanada', '.', 'ĠKey', 'Ġjob', 'Ġresponsibilities', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Resp', 'ons', 'ible', 'Ġfor', 'Ġthe', 'Ġdevelopment', 'Ġand', 'Ġmaintenance', 'Ġof', 'Ġkey', 'Ġsystem', 'Ġfeatures', '.', 'ĠWill', 'Ġwork', 'Ġwith', 'Ġother', 'Ġteam', 'Ġmembers', 'Ġto', 'Ġinvestigate', 'Ġdesign', 'Ġapproaches', ',', 'Ġprototype', 'Ġtechnology', 'Ġand', 'Ġevaluate', 'Ġtechnical', 'Ġfeasibility', '.', 'ĠWill', 'Ġestablish', 'Ġarchitectural', 'Ġprinciples', ',', 'Ġselect', 'Ġdesign', 'Ġpatterns', 'Ġand', 'Ġthen', 'Ġmentor', 'Ġteam', 'Ġmembers', 'Ġon', 'Ġtheir', 'Ġappropriate', 'Ġapplication', '.', 'ĠTeam', 'ĠLocations', ':', 'Toronto', '.', 'ĠVancouver', '.', 'ĠVirtual', 'Ġin', 'ĠCanada', '.', 'ĠKey', 'Ġjob', 'Ġresponsibilities', '.', '</s>']
#
# Pipeline Orchestration – design and development of end to end workflow/pipeline . Assist in development and deployment of automation and operational support strategies. Work in an Agile environment with Scrum teams.
# パイプラインオーケストレーション – エンドツーエンドのワークフロー/パイプラインの設計と開発 . オートメーションと運用支援戦略の開発と導入に役立ちます. Scrumチームとアジャイル環境で作業します.
# deberta_tokens: ['[CLS]', 'P', 'ip', 'eline', 'ĠOrche', 'stration', 'ĠâĢĵ', 'Ġdesign', 'Ġand', 'Ġdevelopment', 'Ġof', 'Ġend', 'Ġto', 'Ġend', 'Ġworkflow', '/', 'p', 'ip', 'eline', 'Ġ.', 'ĠAssist', 'Ġin', 'Ġdevelopment', 'Ġand', 'Ġdeployment', 'Ġof', 'Ġautomation', 'Ġand', 'Ġoperational', 'Ġsupport', 'Ġstrategies', '.', 'ĠWork', 'Ġin', 'Ġan', 'ĠAg', 'ile', 'Ġenvironment', 'Ġwith', 'ĠSc', 'rum', 'Ġteams', '.', '[SEP]']
# roberta_tokens: ['<s>', 'P', 'ip', 'eline', 'ĠOrche', 'stration', 'ĠâĢĵ', 'Ġdesign', 'Ġand', 'Ġdevelopment', 'Ġof', 'Ġend', 'Ġto', 'Ġend', 'Ġworkflow', '/', 'p', 'ip', 'eline', 'Ġ.', 'ĠAssist', 'Ġin', 'Ġdevelopment', 'Ġand', 'Ġdeployment', 'Ġof', 'Ġautomation', 'Ġand', 'Ġoperational', 'Ġsupport', 'Ġstrategies', '.', 'ĠWork', 'Ġin', 'Ġan', 'ĠAg', 'ile', 'Ġenvironment', 'Ġwith', 'ĠSc', 'rum', 'Ġteams', '.', '</s>']
#
# Build API endpoints. Work on Cloud deployment.
# API エンドポイントを構築し、クラウドデプロイメントで作業します。
# deberta_tokens: ['[CLS]', 'Build', 'ĠAPI', 'Ġend', 'points', '.', 'ĠWork', 'Ġon', 'ĠCloud', 'Ġdeployment', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Build', 'ĠAPI', 'Ġend', 'points', '.', 'ĠWork', 'Ġon', 'ĠCloud', 'Ġdeployment', '.', '</s>']
#
# Monitor, diagnose and maintain deployments. Upgrade systems and models whenever needed. Take care of product performance, robustness and reliability. Manage individual project priorities, deadlines and deliverables. General direction of work involved.
# 必要に応じてシステムやモデルをアップグレードし、製品のパフォーマンス、堅牢性、信頼性を保ちます。
# deberta_tokens: ['[CLS]', 'Monitor', ',', 'Ġdiagnose', 'Ġand', 'Ġmaintain', 'Ġdeployments', '.', 'ĠUpgrade', 'Ġsystems', 'Ġand', 'Ġmodels', 'Ġwhenever', 'Ġneeded', '.', 'ĠTake', 'Ġcare', 'Ġof', 'Ġproduct', 'Ġperformance', ',', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', '.', 'ĠMan', 'age', 'Ġindividual', 'Ġproject', 'Ġpriorities', ',', 'Ġdeadlines', 'Ġand', 'Ġdeliver', 'ables', '.', 'ĠGeneral', 'Ġdirection', 'Ġof', 'Ġwork', 'Ġinvolved', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Monitor', ',', 'Ġdiagnose', 'Ġand', 'Ġmaintain', 'Ġdeployments', '.', 'ĠUpgrade', 'Ġsystems', 'Ġand', 'Ġmodels', 'Ġwhenever', 'Ġneeded', '.', 'ĠTake', 'Ġcare', 'Ġof', 'Ġproduct', 'Ġperformance', ',', 'Ġrobust', 'ness', 'Ġand', 'Ġreliability', '.', 'ĠMan', 'age', 'Ġindividual', 'Ġproject', 'Ġpriorities', ',', 'Ġdeadlines', 'Ġand', 'Ġdeliver', 'ables', '.', 'ĠGeneral', 'Ġdirection', 'Ġof', 'Ġwork', 'Ġinvolved', '.', '</s>']
#
# Implementing appropriate ML algorithms. Demonstrable skill in deep learning (Kaggle Medal / Paper / Work / PhD). Research and implement appropriate ML algorithms and tools. Perform statistical analysis and fine-tuning using test results. Train and retrain systems when necessary. Extend existing ML libraries and frameworks. Keep abreast of developments in the field.
# 適切なMLアルゴリズムを実装する. 深い学習における実証可能なスキル (Kaggle Medal / Paper / Work / PhD). 研究と適切なMLアルゴリズムとツールを実装する. テスト結果を使用して統計分析と微調整を行う. 必要に応じてシステムを訓練し、訓練する. 既存のMLライブラリとフレームワークを拡張する. フィールドでの開発の最新を保つ.
# deberta_tokens: ['[CLS]', 'Im', 'plement', 'ing', 'Ġappropriate', 'ĠML', 'Ġalgorithms', '.', 'ĠDemon', 'str', 'able', 'Ġskill', 'Ġin', 'Ġdeep', 'Ġlearning', 'Ġ(', 'K', 'agg', 'le', 'ĠMedal', 'Ġ/', 'ĠPaper', 'Ġ/', 'ĠWork', 'Ġ/', 'ĠPhD', ').', 'ĠResearch', 'Ġand', 'Ġimplement', 'Ġappropriate', 'ĠML', 'Ġalgorithms', 'Ġand', 'Ġtools', '.', 'ĠPerform', 'Ġstatistical', 'Ġanalysis', 'Ġand', 'Ġfine', '-', 'tun', 'ing', 'Ġusing', 'Ġtest', 'Ġresults', '.', 'ĠTrain', 'Ġand', 'Ġret', 'rain', 'Ġsystems', 'Ġwhen', 'Ġnecessary', '.', 'ĠExtend', 'Ġexisting', 'ĠML', 'Ġlibraries', 'Ġand', 'Ġframeworks', '.', 'ĠKeep', 'Ġab', 're', 'ast', 'Ġof', 'Ġdevelopments', 'Ġin', 'Ġthe', 'Ġfield', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Im', 'plement', 'ing', 'Ġappropriate', 'ĠML', 'Ġalgorithms', '.', 'ĠDemon', 'str', 'able', 'Ġskill', 'Ġin', 'Ġdeep', 'Ġlearning', 'Ġ(', 'K', 'agg', 'le', 'ĠMedal', 'Ġ/', 'ĠPaper', 'Ġ/', 'ĠWork', 'Ġ/', 'ĠPhD', ').', 'ĠResearch', 'Ġand', 'Ġimplement', 'Ġappropriate', 'ĠML', 'Ġalgorithms', 'Ġand', 'Ġtools', '.', 'ĠPerform', 'Ġstatistical', 'Ġanalysis', 'Ġand', 'Ġfine', '-', 'tun', 'ing', 'Ġusing', 'Ġtest', 'Ġresults', '.', 'ĠTrain', 'Ġand', 'Ġret', 'rain', 'Ġsystems', 'Ġwhen', 'Ġnecessary', '.', 'ĠExtend', 'Ġexisting', 'ĠML', 'Ġlibraries', 'Ġand', 'Ġframeworks', '.', 'ĠKeep', 'Ġab', 're', 'ast', 'Ġof', 'Ġdevelopments', 'Ġin', 'Ġthe', 'Ġfield', '.', '</s>']
#
# Define problems and opportunities in a complex business area. Measure the impact of the products developed.
# 複雑なビジネス領域の課題と機会を定義し、開発された製品のインパクトを測定します。
# deberta_tokens: ['[CLS]', 'Def', 'ine', 'Ġproblems', 'Ġand', 'Ġopportunities', 'Ġin', 'Ġa', 'Ġcomplex', 'Ġbusiness', 'Ġarea', '.', 'ĠMeasure', 'Ġthe', 'Ġimpact', 'Ġof', 'Ġthe', 'Ġproducts', 'Ġdeveloped', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Def', 'ine', 'Ġproblems', 'Ġand', 'Ġopportunities', 'Ġin', 'Ġa', 'Ġcomplex', 'Ġbusiness', 'Ġarea', '.', 'ĠMeasure', 'Ġthe', 'Ġimpact', 'Ġof', 'Ġthe', 'Ġproducts', 'Ġdeveloped', '.', '</s>']
#
# Collaborate with teams to support the ML technical roadmap. Offer support and troubleshooting assistance for the ML pipeline, while continuously improving stability, monitoring and alerting along the way. Collaborate on managing the AWS stack which comprises all ML resources. Collaborate on managing ML infrastructure costs.
# ML の技術的なロードマップをサポートするためにチームと協力する ML パイプラインのサポートとトラブルシューティング支援を提供しながら、安定性、モニタリング、アラートを継続的に向上させる すべてのML リソースを含む AWS スタックの管理に協力する ML インフラストラクチャコストの管理に協力する
# deberta_tokens: ['[CLS]', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġteams', 'Ġto', 'Ġsupport', 'Ġthe', 'ĠML', 'Ġtechnical', 'Ġroadmap', '.', 'ĠOffer', 'Ġsupport', 'Ġand', 'Ġtroubles', 'hooting', 'Ġassistance', 'Ġfor', 'Ġthe', 'ĠML', 'Ġpipeline', ',', 'Ġwhile', 'Ġcontinuously', 'Ġimproving', 'Ġstability', ',', 'Ġmonitoring', 'Ġand', 'Ġalert', 'ing', 'Ġalong', 'Ġthe', 'Ġway', '.', 'ĠCollabor', 'ate', 'Ġon', 'Ġmanaging', 'Ġthe', 'ĠAWS', 'Ġstack', 'Ġwhich', 'Ġcomprises', 'Ġall', 'ĠML', 'Ġresources', '.', 'ĠCollabor', 'ate', 'Ġon', 'Ġmanaging', 'ĠML', 'Ġinfrastructure', 'Ġcosts', '.', '[SEP]']
# roberta_tokens: ['<s>', 'Coll', 'abor', 'ate', 'Ġwith', 'Ġteams', 'Ġto', 'Ġsupport', 'Ġthe', 'ĠML', 'Ġtechnical', 'Ġroadmap', '.', 'ĠOffer', 'Ġsupport', 'Ġand', 'Ġtroubles', 'hooting', 'Ġassistance', 'Ġfor', 'Ġthe', 'ĠML', 'Ġpipeline', ',', 'Ġwhile', 'Ġcontinuously', 'Ġimproving', 'Ġstability', ',', 'Ġmonitoring', 'Ġand', 'Ġalert', 'ing', 'Ġalong', 'Ġthe', 'Ġway', '.', 'ĠCollabor', 'ate', 'Ġon', 'Ġmanaging', 'Ġthe', 'ĠAWS', 'Ġstack', 'Ġwhich', 'Ġcomprises', 'Ġall', 'ĠML', 'Ġresources', '.', 'ĠCollabor', 'ate', 'Ġon', 'Ġmanaging', 'ĠML', 'Ġinfrastructure', 'Ġcosts', '.', '</s>']
